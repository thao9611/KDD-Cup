# %%
import pickle
import data_io
import pandas as pd
import numpy as np
from feature_set import *
from collections import defaultdict
import string
import time 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
stopword = set(stopwords.words('english'))
porter = PorterStemmer()

#from Thao_features import *
dataset = {}
dataset['paper'] = pd.read_csv('dataRev2/Paper.csv')[:2000]
trainset = pd.read_csv('dataRev2/Train.csv')
train_confirmed = trainset[['AuthorId', 'ConfirmedPaperIds']].rename(columns = {'ConfirmedPaperIds':'PaperIds'})
targetset = train_confirmed
dataset['paper_author'] = pd.read_csv('dataRev2/PaperAuthor1.csv')

# %%
#for keyword of Papers
def filter_keyword(text):
    for i in string.punctuation: text = text.replace(i,' ')
    words = word_tokenize(text) #split words
    words = [w.lower() for w in words if w.isalpha()] #get rid of punctuation
    words = [w for w in words if w not in  ["keywords"] ]
    stemmed = [porter.stem(w) for w in words]
    return stemmed

# for title of papers
def tokenize(text):
    words = word_tokenize(text) #split words
    words = [w.lower() for w in words if w.isalpha()] #get rid of punctuation
    words =[w for w in words if  not w in stopword]
    stemmed = [porter.stem(w) for w in words]
    return stemmed

#return the keywords of each paper
def paper_keywords(data):
    paper = data['paper']
    paperid = list(paper["Id"])
    paper_keyword = defaultdict(list)

    paper= paper.set_index("Id")
    
    paper['Keyword']= paper['Keyword'].fillna("")
    paper['Title']= paper['Title'].fillna("")

    title = list(paper["Title"])
    cnt = 0
    start_time = time.time()
    titleTokens = []

    print("Start title!!!")
    for t in title:
        cnt += 1
        if (cnt % 100000 == 0):
            print("Count: ", cnt)
            print("Time: ", time.time() - start_time)
        titleTokens.append(tokenize(t))
    paper['Token'] = titleTokens


    #paper['Token'] = paper.Title.map(tokenize)
    print ("Start keyword!!!")

    keywords = list(paper['Keyword'])
    cnt2 = 0
    keywordTokens = []
    for k in keywords:
        cnt2 += 1
        if (cnt2 % 100000 == 0):
            print("Count: ", cnt)
            print("Time: ", time.time() - start_time)
        keywordTokens.append(filter_keyword(k))

    paper['Keyword_pro'] = keywordTokens

    print("Start concatenation!!!")

    #TODO: change all "apply", "map" functions to explicit for loop. Don't use "for loop" in the list because it causes memory limit error.
    #concatenate keyword and token
    keyToken = []
    for i in paperid:
        keyToken.append(list(set(paper.loc[i, 'Keyword_pro'] + paper.loc[i, 'Token'])))
    paper['Key_token'] = keyToken
    for i in paperid:
        paper_keyword[i] = paper.loc[i,'Key_token']

    pickle.dump(paper_keyword, open(data_io.get_paths()["paper_title_tokens"], 'wb'))
    return paper_keyword

#how similar two documents are based on keywords
def common_word(word1, word2):
    for i in word1:
        if i in word2:
            sim += 1
    return sim


def target_paper_and_papers_of_target_author_by_keywords(dataset,author_paper_pairs):
    paper_sim = defaultdict(int)
    trainset = dataset['paper_author']
    keyword = paper_keywords(dataset)
    
    for i in author_paper_pairs:
        trained_paper= list(trainset.loc[trainset["AuthorId"]== i[0], "PaperId"])
        paper_sim[i] = sum(common_word(keyword[i[1]],keyword[j]) for j in trained_paper)
    return paper_sim

def parse_paper_ids(paper_ids_string):
    return paper_ids_string.strip().split()

def parse_targetset(targetset):
    pair_list = []
    author_id_list = targetset['AuthorId']

    for i in range(len(author_id_list)):
        author_id = author_id_list[i]
        papers = targetset[targetset.AuthorId == author_id]['PaperIds'].unique()[0]
        papers = parse_paper_ids(papers)
        for j in range(len(papers)):
            paper_id = int(papers[j])
            pair_list.append( (author_id, paper_id) )
    return list(set(pair_list))

# %%
author_paper_pairs = parse_targetset(targetset)

# %%
thao_f3 = target_paper_and_papers_of_target_author_by_keywords(dataset,author_paper_pairs[:7])

# %%
thao_f3
# Out:
# defaultdict(int,
#             {(205278, 1737961): 0,
#              (433821, 1901940): 0,
#              (1215636, 1791266): 0,
#              (1455231, 467172): 0,
#              (1539933, 1359549): 0,
#              (1589984, 2059890): 0,
#              (1794805, 1802876): 0})

# %%
def process_aff(text):
    for i in string.punctuation: text = text.replace(i,' ')
    words = word_tokenize(text) #split words
    words = [w.lower() for w in words if w.isalpha()] #get rid of punctuation
    words = [w for w in words if w not in list(stopword)]
    words = [w for w in words if w not in  ["institute","univ",'university',"college","department","science","technology",
                                            "de","engineer","lab","dept","falcuty",] ]
    stemmed = [porter.stem(w) for w in words]
    return stemmed
def author_affiliation(data):
    pa = data["paper_author"]
    affiliation = defaultdict(str)
    
    pa['Affiliation'] = pa['Affiliation'].fillna("")
    pa_1 = pd.DataFrame(pd.pivot_table(pa, values = "Affiliation",index = ["AuthorId"], aggfunc = "sum"))
    author = list(pa_1.index)
    for i in author:
        affiliation[i]= process_aff(pa_1.loc[i,"Affiliation"])
    return affiliation

# more efficient approach 
def target_author_and_coauthor_of_target_paper_by_affiliation(dataset,author_paper_pairs):
    pa = dataset["paper_author"]
    aff = author_affiliation(dataset)
    author_sim = defaultdict(int)
    for i in author_paper_pairs:
        coauthor= list(pa.loc[pa["PaperId"]== i[1], "AuthorId"])
        author_sim[i] = sum(common_word(aff[i[0]],aff[j]) for j in coauthor)
    return author_sim

# %%
author_affiliation(dataset)
# Out:
# defaultdict(str,
#             {1229483: [],
#              188421: ['programa',
#               'de',
#               'engenharia',
#               'de',
#               'sistema',
#               'e',
#               'copp',
#               'universidad',
#               'feder',
#               'rio',
#               'de',
#               'janeiro',
#               'brazil'],
#              1245191: ['microsoft', 'research'],
#              290824: [],
#              1105929: ['faculti',
#               'pharmaci',
#               'tehran',
#               'medic',
#               'scienc',
#               'tehran',
#               'iran'],
#              122892: [],
#              1466383: [],
#              757776: [],
#              1024537: ['physic',
#               'california',
#               'lo',
#               'angel',
#               'hilgard',
#               'ave',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              2261013: [],
#              1835034: ['dept', 'comput', 'columbia', 'usa'],
#              981679: [],
#              1892381: [],
#              954373: ['ibm', 'microelectron', 'east', 'fishkil', 'ny', 'usa'],
#              1024033: [],
#              368674: [],
#              429405: [],
#              184368: [],
#              348168: [],
#              319538: ['universidad',
#               'de',
#               'la',
#               'isla',
#               'balear',
#               'departamento',
#               'de',
#               'e',
#               'spain'],
#              1556533: [],
#              2064438: [],
#              1302583: [],
#              794680: [],
#              266298: [],
#              652639: [],
#              602175: ['human',
#               'comput',
#               'interact',
#               'complex',
#               'engin',
#               'system',
#               'carnegi',
#               'mellon'],
#              573505: [],
#              1331267: [],
#              397380: [],
#              557068: [],
#              1089610: [],
#              172107: [],
#              490329: ['key',
#               'laboratori',
#               'molecular',
#               'epigenet',
#               'moe',
#               'northeast',
#               'normal',
#               'changchun',
#               'china'],
#              1429592: [],
#              397402: [],
#              1560670: [],
#              488805: [],
#              516192: ['key',
#               'laboratori',
#               'univers',
#               'wireless',
#               'commun',
#               'beij',
#               'post',
#               'telecommun'],
#              1220706: [],
#              1204323: [],
#              2011236: [],
#              893030: ['ibm', 'microelectron', 'east', 'fishkil', 'ny', 'usa'],
#              2117735: ['dept', 'speech', 'commun'],
#              1429608: [],
#              139371: ['comput', 'read'],
#              417901: [],
#              1048686: ['atom', 'energi', 'research', 'establish', 'harwel'],
#              1510077: [],
#              1917040: [],
#              1433715: ['fermi', 'nation', 'laboratori'],
#              917620: [],
#              916158: [],
#              1196153: [],
#              217210: [],
#              1322346: [],
#              2134146: [],
#              1897835: [],
#              344250: [],
#              1790086: ['center',
#               'artifici',
#               'intellig',
#               'research',
#               'comput',
#               'korea',
#               'advanc'],
#              2130060: [],
#              151695: [],
#              319634: ['center',
#               'x',
#               'ray',
#               'optic',
#               'lawrenc',
#               'berkeley',
#               'nation',
#               'laboratori'],
#              932547: ['asan',
#               'medic',
#               'center',
#               'ulsan',
#               'medicin',
#               'seoul',
#               'korea'],
#              618644: [],
#              52590: [],
#              1204932: ['microsoft', 'research'],
#              37020: [],
#              1826976: [],
#              1257642: [],
#              1203155: [],
#              676014: [],
#              1245361: [],
#              1028274: [],
#              913587: [],
#              32948: [],
#              741561: [],
#              946362: ['institut',
#               'pharmakologi',
#               'heinrich',
#               'hein',
#               'germani'],
#              2256927: [],
#              454847: ['translat',
#               'oncolog',
#               'nation',
#               'center',
#               'tumor',
#               'diseas',
#               'german',
#               'cancer',
#               'research',
#               'center',
#               'dkfz'],
#              528576: ['texa', 'tech'],
#              1151169: [],
#              331970: ['laboratori',
#               'neuro',
#               'imag',
#               'neurolog',
#               'ucla',
#               'school',
#               'medicin',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              463044: [],
#              188614: ['materi',
#               'engin',
#               'program',
#               'texa',
#               'austin',
#               'austin',
#               'texa'],
#              608289: [],
#              929992: [],
#              2072782: [],
#              73935: ['astronomi', 'washington'],
#              73938: [],
#              65747: [],
#              1028308: [],
#              2175189: [],
#              614616: ['microsoft', 'research'],
#              1962206: ['hematolog',
#               'branch',
#               'nation',
#               'heart',
#               'lung',
#               'blood'],
#              56016: ['instrument',
#               'center',
#               'centr',
#               'nanotechnolog',
#               'indian',
#               'roorke',
#               'roorke',
#               'india'],
#              65765: [],
#              172263: ['integr',
#               'inform',
#               'public',
#               'system',
#               'german',
#               'nation',
#               'research',
#               'center',
#               'inform'],
#              1327336: [],
#              655596: [],
#              983277: [],
#              569584: [],
#              409845: [],
#              1368319: ['electr',
#               'comput',
#               'engin',
#               'alabama',
#               'birmingham',
#               'usa'],
#              1962251: [],
#              286988: ['human',
#               'comput',
#               'interact',
#               'complex',
#               'engin',
#               'system',
#               'carnegi',
#               'mellon'],
#              816514: [],
#              266512: [],
#              753937: [],
#              311572: [],
#              586006: [],
#              1497817: [],
#              254233: [],
#              24858: [],
#              311579: [],
#              868636: ['montreal', 'neurolog', 'mcgill'],
#              929243: [],
#              1532191: ['nokia',
#               'research',
#               'centr',
#               'c',
#               'nanosci',
#               'centr',
#               'cambridg',
#               'jj',
#               'thomson',
#               'av',
#               'cambridg',
#               'uk'],
#              2216224: [],
#              90401: ['hematolog', 'oncolog', 'hospit'],
#              1665074: [],
#              549159: [],
#              45788: [],
#              1716524: [],
#              1245485: ['comput', 'wale'],
#              581934: [],
#              2175279: [],
#              53553: [],
#              1561808: [],
#              1134899: [],
#              413065: [],
#              1212728: ['saarland'],
#              1696057: [],
#              61754: [],
#              631099: [],
#              413514: [],
#              229694: [],
#              434496: [],
#              749889: [],
#              1704259: [],
#              409925: [],
#              389447: [],
#              1700171: ['nation',
#               'climat',
#               'data',
#               'center',
#               'noaa',
#               'ashevil',
#               'north',
#               'carolina',
#               'usa'],
#              1818957: ['swiss', 'feder', 'zurich'],
#              1835342: [],
#              1302864: [],
#              602449: ['illinoi', 'urbana', 'champaign'],
#              1593684: [],
#              1495384: [],
#              1442532: [],
#              2269532: [],
#              1163322: [],
#              1864030: [],
#              1233254: ['manag', 'sect', 'gurgaon', 'india'],
#              495976: [],
#              309308: ['california', 'san', 'francisco'],
#              1962346: [],
#              385388: [],
#              882066: [],
#              1671537: ['princeton', 'universityprinceton'],
#              1593716: [],
#              1253751: ['merck',
#               'research',
#               'laboratori',
#               'p',
#               'box',
#               'west',
#               'point',
#               'pa',
#               'usa'],
#              124308: [],
#              504186: ['hangzhou', 'dianzi'],
#              819579: [],
#              463229: [],
#              1626495: [],
#              749952: ['ion',
#               'beam',
#               'physic',
#               'materi',
#               'research',
#               'fzr',
#               'rossendorf',
#               'dresden',
#               'germani'],
#              1192321: ['texa', 'austin', 'austin', 'tx', 'usa'],
#              123269: [],
#              1278342: ['informat',
#               'faculti',
#               'scienc',
#               'lisbon',
#               'campo',
#               'grand',
#               'lisboa',
#               'portug'],
#              90507: [],
#              745871: [],
#              1278352: [],
#              483729: ['inaf',
#               'osservatorio',
#               'astronomico',
#               'di',
#               'capodimont',
#               'via',
#               'moiariello',
#               'napoli',
#               'itali'],
#              1565074: [],
#              1089942: ['nuclear',
#               'engin',
#               'radiolog',
#               'scienc',
#               'michigan',
#               'ann',
#               'arbor',
#               'mi',
#               'usa'],
#              1483160: [],
#              1511833: ['nation', 'taiwan'],
#              806495: [],
#              1601950: [],
#              1438114: [],
#              2052515: [],
#              1626533: ['chemistri', 'wuhan', 'wuhan', 'china'],
#              492932: [],
#              643499: [],
#              278956: [],
#              710045: [],
#              1102257: ['kyushu', 'fukuoka', 'japan', 'fukuoka', 'japan'],
#              1118643: [],
#              1437086: [],
#              1331638: ['southeast', 'instrument', 'engin', 'nanj', 'china'],
#              2064825: ['nation', 'taiwan'],
#              987580: [],
#              1589693: ['physic',
#               'california',
#               'lo',
#               'angel',
#               'hilgard',
#               'ave',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              1122750: ['beihang', 'beij', 'aeronaut', 'astronaut'],
#              1229247: [],
#              364994: [],
#              475589: [],
#              901574: ['microsoft', 'research'],
#              242119: ['experiment', 'hematolog', 'hannov', 'medic', 'school'],
#              1102280: [],
#              807370: ['inaf',
#               'osservatorio',
#               'astronomico',
#               'di',
#               'capodimont',
#               'via',
#               'moiariello',
#               'napoli',
#               'itali'],
#              1774027: ['dupont',
#               'co',
#               'experiment',
#               'station',
#               'wilmington',
#               'de',
#               'usa'],
#              1249740: [],
#              1892818: [],
#              864723: [],
#              2216407: ['coordin',
#               'laboratori',
#               'illinoi',
#               'urbana',
#               'champaign'],
#              348632: [],
#              158775: [],
#              836060: [],
#              877023: [],
#              1233377: [],
#              1671651: ['comput', 'chines', 'academi', 'scienc', 'china'],
#              1136721: [],
#              1561340: [],
#              139754: [],
#              1044972: [],
#              2036206: [],
#              2195956: [],
#              180053: ['hematolog', 'erasmu', 'medic', 'center'],
#              619001: ['chemistri', 'wuhan', 'wuhan', 'china'],
#              2040315: [],
#              356860: ['comput', 'read'],
#              279038: [],
#              98815: [],
#              668163: [],
#              11855: ['translat',
#               'oncolog',
#               'nation',
#               'center',
#               'tumor',
#               'diseas',
#               'german',
#               'cancer',
#               'research',
#               'center',
#               'dkfz'],
#              389637: [],
#              1491462: [],
#              422411: [],
#              2188717: ['belgrad',
#               'forestri',
#               'faculti',
#               'wood',
#               'kneza',
#               'belgrad',
#               'yugoslavia'],
#              1647123: ['microsoft', 'research'],
#              139800: [],
#              1077785: [],
#              2032155: [],
#              1446428: [],
#              1698565: [],
#              864807: [],
#              1266219: ['ashoka', 'changemak'],
#              959024: ['institut', 'fur', 'klinisch', 'anaesthesiologi'],
#              569906: [],
#              1298998: [],
#              917250: [],
#              1630780: [],
#              1675837: [],
#              1458750: [],
#              1421408: [],
#              2163267: [],
#              1679940: ['school', 'comput', 'commun', 'hunan'],
#              533065: [],
#              8779: [],
#              401998: [],
#              1757775: [],
#              1847888: [],
#              1684920: [],
#              2089554: [],
#              606803: [],
#              2208344: [],
#              430681: [],
#              258650: [],
#              1331803: [],
#              1487454: ['dpto',
#               'facultad',
#               'de',
#               'cc',
#               'u',
#               'complutens',
#               'madrid',
#               'spain'],
#              856671: [],
#              856673: [],
#              1000036: ['busan', 'nation', 'hospit', 'busan', 'korea'],
#              405606: [],
#              1978983: [],
#              1548904: [],
#              90730: [],
#              299629: [],
#              242287: [],
#              695616: [],
#              762482: [],
#              225907: [],
#              688758: [],
#              768105: ['associ',
#               'laboratori',
#               'plasma',
#               'nation',
#               'space',
#               'research',
#               'j',
#               'campo',
#               'paulo',
#               'brazil'],
#              1303165: [],
#              963198: [],
#              2003584: [],
#              33409: ['coordin',
#               'laboratori',
#               'electr',
#               'comput',
#               'engin',
#               'illinoi',
#               'urbana',
#               'champaign'],
#              1675907: [],
#              795268: ['comput', 'read'],
#              1094277: [],
#              1282694: [],
#              635528: [],
#              1385099: [],
#              758412: [],
#              885389: [],
#              1220717: [],
#              463507: [],
#              1004180: [],
#              447127: ['pennsylvania', 'pennsylvania', 'purdu'],
#              656024: [],
#              107163: [],
#              492188: [],
#              725661: [],
#              1049246: ['de', 'cegep', 'jonquier'],
#              1487520: ['biomed',
#               'engin',
#               'john',
#               'hopkin',
#               'baltimor',
#               'md',
#               'usa'],
#              1017968: [],
#              8866: [],
#              238243: [],
#              1428448: [],
#              1122983: ['materi',
#               'engin',
#               'china',
#               'anhui',
#               'hefei',
#               'p',
#               'r',
#               'china'],
#              86697: [],
#              1540778: [],
#              1602219: ['school',
#               'comput',
#               'nation',
#               'defens',
#               'changsha',
#               'china'],
#              119468: ['coordin',
#               'laboratori',
#               'illinoi',
#               'urbana',
#               'champaign'],
#              254637: [],
#              1716913: ['asan',
#               'medic',
#               'center',
#               'ulsan',
#               'medicin',
#               'seoul',
#               'korea'],
#              1241778: [],
#              221879: [],
#              962676: [],
#              527818: [],
#              1364768: [],
#              631491: [],
#              504516: [],
#              336583: ['merck',
#               'research',
#               'laboratori',
#               'p',
#               'box',
#               'west',
#               'point',
#               'pa',
#               'usa'],
#              193234: ['chemistri', 'northern', 'illinoi', 'dekalb', 'il', 'u'],
#              1028825: [],
#              832220: ['brain', 'bodi', 'centr', 'nottingham', 'de'],
#              2020062: [],
#              1356581: [],
#              1303266: ['seoul', 'nation'],
#              2069220: [],
#              1094376: [],
#              1123049: [],
#              1794796: [],
#              832238: [],
#              37615: [],
#              1520374: [],
#              1381805: [],
#              168700: [],
#              426794: [],
#              1647360: [],
#              1889026: [],
#              1393413: ['ibm'],
#              1573638: [],
#              598792: [],
#              283402: ['met', 'offic', 'hadley', 'centr', 'exet', 'uk'],
#              2056971: ['dept', 'mech', 'shiraz'],
#              1966860: [],
#              176911: [],
#              757108: [],
#              1327891: [],
#              795412: ['leibniz',
#               'center',
#               'tropic',
#               'marin',
#               'ecolog',
#               'fahrenheitstr',
#               'bremen',
#               'germani'],
#              1721110: [],
#              2126616: ['cambridg'],
#              1291033: [],
#              566043: ['materi',
#               'engin',
#               'china',
#               'anhui',
#               'hefei',
#               'p',
#               'r',
#               'china'],
#              1119005: ['merck',
#               'research',
#               'laboratori',
#               'p',
#               'box',
#               'west',
#               'point',
#               'pa',
#               'usa'],
#              131870: [],
#              1377056: [],
#              2282274: [],
#              1385251: [],
#              979748: [],
#              2154630: [],
#              1229610: [],
#              717611: [],
#              1053484: [],
#              418605: [],
#              1872687: [],
#              2057013: ['astronomi', 'pennsylvania', 'state'],
#              1556274: ['state',
#               'key',
#               'laboratori',
#               'powder',
#               'metallurgi',
#               'central',
#               'south',
#               'changsha',
#               'pr',
#               'china'],
#              74555: [],
#              217916: [],
#              111421: ['de', 'montfort'],
#              1553217: [],
#              1102658: [],
#              1934147: [],
#              1471300: [],
#              1441249: [],
#              1457914: [],
#              1690423: [],
#              230221: ['heidelberg'],
#              303950: [],
#              1782607: ['depart',
#               'radiolog',
#               'medicin',
#               'psychiatri',
#               'california',
#               'san',
#               'francisco',
#               'san',
#               'francisco',
#               'ca',
#               'usa'],
#              234321: [],
#              418646: [],
#              2159447: [],
#              1586013: [],
#              922462: [],
#              357215: ['soonchunhyang',
#               'bucheon',
#               'hospit',
#               'bucheon',
#               'korea'],
#              33595: ['mathemat', 'mit', 'cambridg', 'usa'],
#              1352552: [],
#              1995580: ['inform', 'nara'],
#              413842: ['institut',
#               'de',
#               'recherch',
#               'en',
#               'informatiqu',
#               'de',
#               'toulous',
#               'rout',
#               'de',
#               'narbonn',
#               'f',
#               'toulous',
#               'cedex'],
#              770877: [],
#              1463152: [],
#              1930098: [],
#              186515: ['cardiolog',
#               'divis',
#               'intern',
#               'medicin',
#               'chungnam',
#               'nation',
#               'hospit',
#               'chungnam',
#               'nation',
#               'deajeon',
#               'korea'],
#              1479540: [],
#              1471349: [],
#              1123190: [],
#              609769: ['network',
#               'graduat',
#               'school',
#               'inform',
#               'system',
#               'electro',
#               'commun'],
#              1826964: [],
#              650545: ['key',
#               'laboratori',
#               'veget',
#               'ecolog',
#               'school',
#               'life',
#               'scienc',
#               'northeast',
#               'normal',
#               'changchun',
#               'china'],
#              979835: ['texa', 'tech'],
#              1237884: ['translat',
#               'oncolog',
#               'nation',
#               'center',
#               'tumor',
#               'diseas',
#               'german',
#               'cancer',
#               'research',
#               'center',
#               'dkfz'],
#              550378: [],
#              1516414: [],
#              2159490: [],
#              365443: [],
#              1528710: ['cairo', 'microsoft', 'innov'],
#              926601: [],
#              1037194: ['rmit',
#               'melbourn',
#               'australiaschool',
#               'electr',
#               'comput',
#               'engin',
#               'rmit',
#               'melbourn',
#               'vic',
#               'australia'],
#              414603: [],
#              21388: [],
#              713614: [],
#              1643409: ['unm',
#               'nsf',
#               'center',
#               'micro',
#               'engin',
#               'ceram',
#               'new',
#               'mexico',
#               'albuquerqu',
#               'nm',
#               'usa'],
#              2061203: ['belgrad',
#               'chemistri',
#               'metallurgyunivers',
#               'belgrad',
#               'electrochemistri',
#               'ictm',
#               'karnegijeva',
#               'belgrad',
#               'yugoslavia'],
#              1192852: [],
#              336789: [],
#              1778584: [],
#              652185: [],
#              1770397: [],
#              699825: [],
#              2163618: [],
#              2220963: [],
#              844708: [],
#              1856422: [],
#              619431: ['lancast', 'lancast', 'comput', 'uk'],
#              2180008: ['de', 'cegep', 'jonquier'],
#              369579: [],
#              701356: ['artifici', 'intellig', 'group', 'faculti', 'bielefeld'],
#              865198: [],
#              971697: [],
#              394164: [],
#              1430454: [],
#              1618873: [],
#              1807291: [],
#              93570: ['illinoi', 'chicago'],
#              525251: [],
#              689094: [],
#              1328071: [],
#              1983433: [],
#              1151946: ['translat',
#               'oncolog',
#               'nation',
#               'center',
#               'tumor',
#               'diseas',
#               'german',
#               'cancer',
#               'research',
#               'center',
#               'dkfz'],
#              1975800: [],
#              979929: [],
#              820187: [],
#              78813: [],
#              623583: [],
#              2245601: [],
#              1143778: ['california', 'lo', 'angel'],
#              910307: [],
#              1115109: [],
#              2036712: [],
#              927228: [],
#              21482: ['human',
#               'comput',
#               'interact',
#               'complex',
#               'engin',
#               'system',
#               'carnegi',
#               'mellon'],
#              1139693: [],
#              1852398: [],
#              1369071: [],
#              492528: [],
#              2192369: ['institut', 'neurosci', 'et', 'pari', 'vi'],
#              1033202: ['tennesse',
#               'atom',
#               'energi',
#               'commiss',
#               'agricultur',
#               'research',
#               'program',
#               'oak',
#               'ridg',
#               'tennesse'],
#              1369077: [],
#              1242106: [],
#              798890: [],
#              279550: [],
#              2122753: [],
#              1713154: ['nation',
#               'histoir',
#               'naturelleentomologi',
#               'cnr',
#               'umr',
#               'nation',
#               'histoir',
#               'naturel',
#               'rue',
#               'buffon',
#               'pari',
#               'franc'],
#              530596: ['brain', 'bodi', 'centr', 'nottingham'],
#              1098759: [],
#              1299465: ['nanj', 'electron', 'devic', 'nanj', 'china'],
#              1311754: ['savoi', 'franc'],
#              185355: [],
#              1946639: [],
#              1549328: ['chair', 'inform', 'system', 'kassel'],
#              1504274: [],
#              373779: [],
#              1344532: ['ibm', 'j', 'watson', 'research', 'center'],
#              558101: [],
#              949081: [],
#              304152: [],
#              103450: [],
#              181275: [],
#              2061340: [],
#              316446: [],
#              1639457: [],
#              181283: [],
#              2229284: [],
#              648229: [],
#              267302: [],
#              2167849: [],
#              1541162: [],
#              893995: [],
#              2119692: ['electr', 'comput', 'engin', 'alberta'],
#              2011997: ['comput'],
#              1553456: ['advanc',
#               'technolog',
#               'applic',
#               'center',
#               'cenatav',
#               'cuba'],
#              2274353: ['physic', 'feder', 'curitiba', 'brazil'],
#              1954654: ['princeton'],
#              906294: [],
#              2167863: [],
#              758843: [],
#              1360957: ['asan',
#               'medic',
#               'center',
#               'ulsan',
#               'medicin',
#               'seoul',
#               'korea'],
#              546997: [],
#              1147969: [],
#              607299: [],
#              943176: ['dept', 'speech', 'commun'],
#              630284: ['geolog',
#               'geophys',
#               'yale',
#               'po',
#               'box',
#               'new',
#               'ct',
#               'usa'],
#              148555: ['universidad',
#               'nacion',
#               'de',
#               'colombia',
#               'sede',
#               'manizal',
#               'colombia'],
#              1952610: [],
#              1737807: [],
#              353361: ['tsinghua', 'china'],
#              107602: [],
#              353365: [],
#              169046: [],
#              626873: [],
#              32498: [],
#              769551: [],
#              1500252: ['princeton'],
#              415930: [],
#              746590: [],
#              2192482: [],
#              58468: [],
#              1316895: ['neuroradiolog',
#               'divis',
#               'phipp',
#               'radiolog',
#               'radiolog',
#               'john',
#               'hopkin',
#               'baltimor',
#               'md',
#               'usa'],
#              412519: [],
#              521325: [],
#              951408: [],
#              537713: [],
#              1406067: [],
#              922740: [],
#              607351: ['materi',
#               'engin',
#               'program',
#               'texa',
#               'austin',
#               'austin',
#               'texa'],
#              912234: ['physic', 'pennsylvania'],
#              1167552: [],
#              1393794: [],
#              195435: [],
#              652422: [],
#              2265281: [],
#              1217673: [],
#              136330: [],
#              840844: [],
#              1574030: [],
#              1160728: ['eti',
#               'de',
#               'cergi',
#               'pontois',
#               'ensea',
#               'neurocybernet',
#               'team',
#               'av',
#               'du',
#               'ponceau',
#               'cergi',
#               'pontois',
#               'cedex',
#               'franc'],
#              1156243: [],
#              398485: [],
#              1864855: [],
#              451736: [],
#              1422191: [],
#              820380: ['school', 'comput', 'commun', 'hunan'],
#              545950: [],
#              1569952: [],
#              2188451: [],
#              1890502: [],
#              1143976: ['manag',
#               'vienna',
#               'bruenner',
#               'strass',
#               'vienna',
#               'austria'],
#              296107: [],
#              656557: [],
#              1540296: ['st', 'joseph'],
#              1067847: [],
#              101515: [],
#              1950902: ['physic', 'feder', 'curitiba', 'brazil'],
#              639860: [],
#              1471674: [],
#              1217724: [],
#              955581: [],
#              1295552: [],
#              1426976: [],
#              2093919: [],
#              701637: ['virginia', 'tech', 'dept', 'comput'],
#              971975: [],
#              2184394: ['comput', 'chines', 'academi', 'scienc', 'china'],
#              935115: [],
#              70860: [],
#              595490: [],
#              2200782: [],
#              1045711: ['san',
#               'raffael',
#               'telethon',
#               'gene',
#               'therapi',
#               'hsr',
#               'tiget',
#               'universitã',
#               'di',
#               'roma',
#               'tor',
#               'vergata'],
#              615632: [],
#              704035: [],
#              1361108: [],
#              201943: ['robert',
#               'bosch',
#               'gmbh',
#               'hildesheim',
#               'germani',
#               'hildesheim',
#               'germani'],
#              808153: ['unm',
#               'nsf',
#               'center',
#               'micro',
#               'engin',
#               'ceram',
#               'new',
#               'mexico',
#               'albuquerqu',
#               'nm',
#               'usa'],
#              742949: [],
#              1354543: [],
#              398562: ['manag',
#               'vienna',
#               'bruenner',
#               'strass',
#               'vienna',
#               'austria'],
#              496867: ['japan'],
#              120037: [],
#              2204903: [],
#              2131176: ['climat',
#               'research',
#               'unit',
#               'school',
#               'environment',
#               'scienc',
#               'east',
#               'anglia',
#               'norwich',
#               'uk'],
#              5357: [],
#              607470: [],
#              207741: [],
#              238835: [],
#              879486: [],
#              2172150: [],
#              586999: [],
#              787705: [],
#              967930: [],
#              1017083: [],
#              636159: [],
#              1709315: [],
#              1357062: [],
#              685321: [],
#              1193229: ['inria', 'franc'],
#              931086: ['firenz',
#               'dipartimento',
#               'di',
#               'matematica',
#               'vial',
#               'morgagni',
#               'firenz',
#               'itali'],
#              722191: [],
#              1500433: [],
#              742275: ['deutsch',
#               'telekom',
#               'berkom',
#               'gmbh',
#               'berlin',
#               'germani',
#               'berlin',
#               'germani'],
#              663086: [],
#              236682: ['john', 'hopkin'],
#              894232: [],
#              1871877: [],
#              144671: [],
#              1217414: [],
#              2061607: ['sharif'],
#              1615146: [],
#              818738: [],
#              1680687: [],
#              445869: [],
#              787761: [],
#              587063: [],
#              1504568: [],
#              959803: [],
#              193852: [],
#              48693: [],
#              1574208: [],
#              1234241: [],
#              976195: [],
#              1492292: [],
#              255301: ['barrow',
#               'neurolog',
#               'st',
#               'joseph',
#               'hospit',
#               'medic',
#               'center',
#               'phoenix',
#               'az',
#               'usa'],
#              1103174: [],
#              996681: [],
#              1074507: [],
#              1729869: [],
#              2094414: ['human',
#               'comput',
#               'interact',
#               'complex',
#               'engin',
#               'system',
#               'carnegi',
#               'mellon'],
#              191373: [],
#              1707289: [],
#              1063215: [],
#              2200914: ['comput', 'sheffield', 'sheffield', 'uk'],
#              407779: [],
#              1328468: [],
#              160654: [],
#              1516886: ['cern'],
#              304472: [],
#              2009316: [],
#              669019: [],
#              144733: [],
#              133709: [],
#              2057567: ['center',
#               'artifici',
#               'intellig',
#               'research',
#               'comput',
#               'korea',
#               'advanc'],
#              275808: [],
#              2180451: [],
#              525669: ['jet',
#               'propuls',
#               'laboratori',
#               'california',
#               'oak',
#               'grove',
#               'drive',
#               'pasadena',
#               'ca',
#               'unit',
#               'state'],
#              1836390: ['physic',
#               'california',
#               'lo',
#               'angel',
#               'hilgard',
#               'ave',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              892360: [],
#              615787: ['illinoi'],
#              685423: ['soongsil'],
#              456048: [],
#              1566067: [],
#              1324404: [],
#              1381750: [],
#              1209919: [],
#              1295742: [],
#              968063: [],
#              808320: [],
#              1033602: [],
#              337283: [],
#              1791364: ['hallym', 'sacr', 'heart', 'hospit', 'anyang', 'korea'],
#              542088: [],
#              1103242: [],
#              1254799: [],
#              1833880: [],
#              1713554: [],
#              546371: [],
#              2249412: ['comput', 'regina'],
#              1566102: [],
#              205721: [],
#              411032: [],
#              1729948: ['inorgan',
#               'materi',
#               'research',
#               'program',
#               'school',
#               'physic',
#               'chemic',
#               'scienc',
#               'queensland'],
#              1406365: [],
#              521630: ['cairo', 'microsoft', 'innov'],
#              1291680: ['biochemisch', 'institut', 'universit', 'freiburg'],
#              1201570: [],
#              1586598: ['network',
#               'graduat',
#               'school',
#               'inform',
#               'system',
#               'electro',
#               'commun'],
#              2217385: [],
#              1557930: [],
#              2090411: [],
#              546220: [],
#              452013: [],
#              1398190: [],
#              1222066: ['nber', 'contributor'],
#              2278836: [],
#              1144245: [],
#              1361335: ['chonbuk', 'nation', 'hospit', 'jeonju', 'korea'],
#              1938872: [],
#              284091: [],
#              1156541: [],
#              2086335: [],
#              1865153: [],
#              673218: ['bremen'],
#              1865155: [],
#              34244: [],
#              2045384: ['metallurgi', 'liverpool'],
#              26060: [],
#              636365: [],
#              1295824: [],
#              2135508: ['deutsch',
#               'thomson',
#               'brandt',
#               'gmbh',
#               'hanov',
#               'germani',
#               'hanov',
#               'germani'],
#              952569: [],
#              994895: ['robert',
#               'bosch',
#               'gmbh',
#               'hildesheim',
#               'germani',
#               'hildesheim',
#               'germani'],
#              103904: [],
#              2196961: [],
#              1291174: [],
#              153063: ['sixti', 'southern', 'california', 'condominium'],
#              124392: [],
#              1497340: ['mayo', 'clinic', 'rochest', 'mn', 'usa'],
#              308714: [],
#              1762795: [],
#              1054188: [],
#              400978: [],
#              472561: [],
#              292338: [],
#              669173: [],
#              1213943: [],
#              894456: [],
#              574972: ['nuclear',
#               'engin',
#               'radiolog',
#               'scienc',
#               'michigan',
#               'ann',
#               'arbor',
#               'mi',
#               'usa'],
#              1029629: [],
#              1865214: [],
#              1979904: [],
#              1324545: [],
#              2090499: [],
#              67077: ['inform', 'secur', 'institut', 'sichuan'],
#              1472006: [],
#              1697287: [],
#              1394184: [],
#              1562125: [],
#              34318: [],
#              443992: [],
#              1996306: [],
#              837142: [],
#              1553943: [],
#              923160: [],
#              307816: [],
#              751131: [],
#              1594970: ['faculti',
#               'pharmaci',
#               'tehran',
#               'medic',
#               'scienc',
#               'tehran',
#               'iran'],
#              2061855: [],
#              1672736: [],
#              787848: [],
#              976419: [],
#              1914404: [],
#              636453: ['electr',
#               'comput',
#               'engin',
#               'alabama',
#               'birmingham',
#               'usa'],
#              30604: [],
#              120363: [],
#              1439282: [],
#              2229812: [],
#              1336886: [],
#              489015: [],
#              767545: [],
#              1295930: [],
#              71263: ['orbit',
#               'scienc',
#               'corp',
#               'nasa',
#               'goddard',
#               'space',
#               'flight',
#               'center',
#               'code',
#               'greenbelt',
#               'md',
#               'usa'],
#              1951295: [],
#              1496640: ['laboratori',
#               'neuro',
#               'imag',
#               'neurolog',
#               'ucla',
#               'school',
#               'medicin',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              1349187: [],
#              1569718: ['center',
#               'x',
#               'ray',
#               'optic',
#               'lawrenc',
#               'berkeley',
#               'nation',
#               'laboratori'],
#              931425: [],
#              992840: [],
#              2061897: ['ontario'],
#              54858: [],
#              1304140: [],
#              1119824: ['comput', 'sheffield', 'sheffield', 'uk'],
#              1508945: [],
#              1267283: [],
#              1320533: [],
#              1644118: [],
#              2180696: ['massachusett'],
#              1705572: [],
#              2131546: [],
#              206427: [],
#              935517: ['waseda',
#               'universitygradu',
#               'school',
#               'inform',
#               'product',
#               'system',
#               'waseda'],
#              63071: [],
#              2147937: [],
#              1901499: [],
#              2045540: ['princeton'],
#              2094693: [],
#              1767015: [],
#              1944501: [],
#              1312361: [],
#              407151: [],
#              1140336: [],
#              2207336: [],
#              271987: [],
#              1291892: [],
#              1807989: ['institut', 'fur', 'klinisch', 'anaesthesiologi'],
#              280184: ['microsoft', 'research', 'microsoft', 'corpor'],
#              902777: [],
#              2258557: ['oregon'],
#              775808: [],
#              785344: [],
#              1042050: [],
#              144903: [],
#              1177227: ['nanj', 'electron', 'devic', 'nanj', 'china'],
#              919180: ['graduat',
#               'school',
#               'inform',
#               'product',
#               'system',
#               'waseda'],
#              2287245: ['manag', 'sect', 'gurgaon', 'india'],
#              951951: [],
#              177808: [],
#              99985: ['siemen', 'ag', 'corpor'],
#              1006743: [],
#              1820309: [],
#              1925401: ['microsoft'],
#              1414808: [],
#              1513117: ['laboratori',
#               'neurosci',
#               'nation',
#               'age',
#               'intramur',
#               'research',
#               'program',
#               'baltimor',
#               'md',
#               'usa'],
#              214689: [],
#              688411: [],
#              157349: [],
#              718504: ['dept', 'physic'],
#              1959597: [],
#              1846658: [],
#              2082419: [],
#              2201270: [],
#              2164408: ['advanc',
#               'technolog',
#               'applic',
#               'center',
#               'cenatav',
#               'cuba'],
#              669370: [],
#              665887: [],
#              1906366: ['texa', 'austin', 'comput', 'scienc', 'usa', 'usa'],
#              1095359: [],
#              1210050: ['eti',
#               'de',
#               'cergi',
#               'pontois',
#               'ensea',
#               'neurocybernet',
#               'team',
#               'av',
#               'du',
#               'ponceau',
#               'cergi',
#               'pontois',
#               'cedex',
#               'franc'],
#              1361604: [],
#              1648325: [],
#              1988295: [],
#              1025737: [],
#              984785: [],
#              128724: ['microsoft', 'redmond'],
#              2021077: [],
#              1677019: ['comput', 'georgia', 'atlanta'],
#              354021: [],
#              2160358: [],
#              126500: [],
#              587497: [],
#              2057963: [],
#              628460: [],
#              956145: ['instituto', 'de', 'f', 'ãµsica', 'teorica'],
#              1009395: [],
#              2221814: [],
#              1810729: [],
#              1548100: [],
#              1070841: [],
#              2221820: [],
#              1599230: [],
#              1564740: [],
#              1987956: ['center',
#               'x',
#               'ray',
#               'optic',
#               'lawrenc',
#               'berkeley',
#               'nation',
#               'laboratori'],
#              644868: [],
#              1423112: [],
#              59145: [],
#              1828620: [],
#              2197261: [],
#              251664: ['civil',
#               'environment',
#               'engin',
#               'california',
#               'berkeley',
#               'ca',
#               'usa'],
#              2164501: [],
#              67350: ['translat',
#               'oncolog',
#               'nation',
#               'center',
#               'tumor',
#               'diseas',
#               'german',
#               'cancer',
#               'research',
#               'center',
#               'dkfz'],
#              2193711: [],
#              972575: ['cairo', 'microsoft', 'innov'],
#              390944: [],
#              1005345: [],
#              1738530: [],
#              1414107: [],
#              886566: [],
#              1443623: [],
#              874282: ['laboratoir',
#               'informatiqu',
#               'fondamental',
#               'de',
#               'lill'],
#              591660: [],
#              1392343: [],
#              673587: [],
#              1283895: [],
#              1067316: [],
#              1106911: [],
#              988989: [],
#              202558: [],
#              1394496: [],
#              1746753: [],
#              767811: [],
#              1369430: [],
#              1992518: [],
#              1906503: ['pulvertaft',
#               'hand',
#               'centr',
#               'derbyshir',
#               'royal',
#               'infirmari',
#               'derbi',
#               'uk'],
#              1500812: [],
#              2132279: [],
#              2266956: [],
#              2185037: [],
#              120654: [],
#              833359: ['physic',
#               'faculti',
#               'engin',
#               'chuo',
#               'kasuga',
#               'bunkyo',
#               'ku',
#               'tokyo',
#               'japan'],
#              1984336: [],
#              2089272: [],
#              714578: [],
#              2061283: [],
#              1567716: ['beihang', 'beij', 'aeronaut', 'astronaut'],
#              1623900: [],
#              255838: ['key',
#               'laboratori',
#               'veget',
#               'ecolog',
#               'school',
#               'life',
#               'scienc',
#               'northeast',
#               'normal',
#               'changchun',
#               'china'],
#              374624: [],
#              1574753: [],
#              2017124: [],
#              1181542: [],
#              2246504: ['laboratori',
#               'neuro',
#               'imag',
#               'neurolog',
#               'ucla',
#               'school',
#               'medicin',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              452457: [],
#              198507: ['cardiolog',
#               'divis',
#               'intern',
#               'medicin',
#               'chungnam',
#               'nation',
#               'hospit',
#               'chungnam',
#               'nation',
#               'deajeon',
#               'korea'],
#              258661: [],
#              2278752: [],
#              812919: [],
#              178041: [],
#              470723: [],
#              618598: [],
#              1021822: [],
#              2082688: [],
#              1091458: ['pulvertaft',
#               'hand',
#               'centr',
#               'derbyshir',
#               'royal',
#               'infirmari',
#               'derbi',
#               'uk'],
#              771971: ['nuclear',
#               'engin',
#               'radiolog',
#               'scienc',
#               'michigan',
#               'ann',
#               'arbor',
#               'mi',
#               'usa'],
#              1664548: [],
#              182150: ['faculti',
#               'pharmaci',
#               'tehran',
#               'medic',
#               'scienc',
#               'tehran',
#               'iran'],
#              1906568: [],
#              1750679: ['network',
#               'graduat',
#               'school',
#               'inform',
#               'system',
#               'electro',
#               'commun'],
#              956300: [],
#              1070997: [],
#              2131862: [],
#              1144728: [],
#              1841483: [],
#              1410972: [],
#              1423262: [],
#              10565: [],
#              708437: [],
#              1334729: [],
#              1554339: ['nber', 'contributor'],
#              358726: [],
#              128935: ['coordin',
#               'laboratori',
#               'illinoi',
#               'urbana',
#               'champaign'],
#              1435563: [],
#              1828781: [],
#              587694: [],
#              1992623: [],
#              2103221: [],
#              1791927: [],
#              698296: [],
#              2082748: ['belgrad',
#               'forestri',
#               'faculti',
#               'wood',
#               'kneza',
#               'belgrad',
#               'yugoslavia'],
#              1320893: [],
#              433824: [],
#              2009419: [],
#              2033604: [],
#              755655: [],
#              2062281: ['universidad', 'de', 'puerto', 'rico'],
#              1476555: ['state',
#               'key',
#               'laboratori',
#               'advanc',
#               'metal',
#               'materi',
#               'beij',
#               'beij',
#               'pr',
#               'china'],
#              862156: [],
#              1591246: [],
#              886735: [],
#              690128: [],
#              1542100: [],
#              2156504: [],
#              296921: ['technisch',
#               'berlin',
#               'institut',
#               'atomar',
#               'physik',
#               'und',
#               'fachdidaktik',
#               'hardenbergstr',
#               'berlin',
#               'germani',
#               'de'],
#              788442: ['center',
#               'cosmolog',
#               'particl',
#               'physic',
#               'physic',
#               'new',
#               'york'],
#              1611739: [],
#              1152989: [],
#              845791: ['merck',
#               'research',
#               'laboratori',
#               'p',
#               'box',
#               'west',
#               'point',
#               'pa',
#               'usa'],
#              858080: [],
#              1853411: [],
#              1611750: ['cairo', 'microsoft', 'innov'],
#              377169: ['asan',
#               'medic',
#               'center',
#               'ulsan',
#               'medicin',
#               'seoul',
#               'korea'],
#              993256: [],
#              1501165: ['comput', 'leicest', 'road', 'leicest', 'uk'],
#              1869806: [],
#              1247218: [],
#              301046: ['commun', 'wuppert'],
#              1547945: ['california', 'lo', 'angel'],
#              1484792: [],
#              710649: [],
#              428026: ['washington'],
#              1632251: ['biomed', 'research', 'georg', 'speyer', 'hau'],
#              686078: [],
#              768000: [],
#              2088619: [],
#              563204: [],
#              59398: [],
#              2180097: [],
#              2230280: ['asan',
#               'medic',
#               'center',
#               'ulsan',
#               'medicin',
#               'seoul',
#               'korea'],
#              315052: [],
#              1648084: [],
#              350222: [],
#              1218575: [],
#              1841169: [],
#              1894421: ['princeton'],
#              423959: ['veterinari',
#               'medicin',
#               'tulan',
#               'nation',
#               'primat',
#               'research',
#               'center',
#               'three',
#               'river',
#               'road',
#               'covington',
#               'la',
#               'usa'],
#              804635: [],
#              1947676: [],
#              2209821: [],
#              1624095: [],
#              1161249: ['de'],
#              1890341: [],
#              1189929: [],
#              866346: [],
#              1706028: ['key',
#               'laboratori',
#               'veget',
#               'ecolog',
#               'school',
#               'life',
#               'scienc',
#               'northeast',
#               'normal',
#               'changchun',
#               'china'],
#              1659229: ['universitã',
#               'parthenop',
#               'via',
#               'de',
#               'gasperi',
#               'napoli',
#               'itali'],
#              862256: [],
#              2189362: [],
#              407603: [],
#              821305: [],
#              2246714: [],
#              436283: [],
#              55356: [],
#              1370173: [],
#              1068832: [],
#              235584: ['physic',
#               'california',
#               'lo',
#               'angel',
#               'hilgard',
#               'ave',
#               'lo',
#               'angel',
#               'ca',
#               'usa'],
#              444768: [],
#              1906754: [],
#              1729547: ['pulvertaft',
#               'hand',
#               'centr',
#               'derbyshir',
#               'royal',
#               'infirmari',
#               'derbi',
#               'uk'],
#              1648708: [],
#              477253: [],
#              788550: [],
#              92232: [],
#              982028: ['stanford'],
#              1709752: [],
#              2074708: ['tokyodepart',
#               'network',
#               'graduat',
#               'school',
#               'inform',
#               'system',
#               'electro',
#               'commun'],
#              1771605: [],
#              1325142: [],
#              ...})

# %%
pa = dataset["paper_author"]
if True:
    affiliation = defaultdict(str)
    
    pa['Affiliation'] = pa['Affiliation'].fillna("")
    pa_1 = pd.DataFrame(pd.pivot_table(pa, values = "Affiliation",index = ["AuthorId"], aggfunc = "sum"))
    author = list(pa_1.index)
    for i in author:
        #print (type(pa_1.loc[i,"Affiliation"]))
        affiliation[i]= process(str(pa_1.loc[i,"Affiliation"]))

# %%
if True:
    pa['Affiliation'] = pa['Affiliation'].fillna("")
    pa_1 = pd.DataFrame(pd.pivot_table(pa, values = "Affiliation",index = ["AuthorId"], aggfunc = "sum"))
    author = list(pa_1.index)
    pa_1["Affiliation"]

# %%
list(pa_1.loc[pa_1["Affiliation"]!= "","Affiliation"])
# Out:
# ['Chonbuk National University Hospital, Jeonju, Korea',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Istituto di Ricerche Farmacologiche â€˜Mario Negriâ€™, Via La Masa 19, 20156 Milano, ItalyMario Negri Institute Pharmacology Research',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'Coordinated Science Laboratory|Department of Electrical and Computer Engineering|University of Illinois at Urbana-Champaign',
#  'Department of Mathematics, MIT, Cambridge, MA 02139, USA',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Institute Instrumentation Center and Centre of Nanotechnology, Indian Institute of Technology Roorkee, Roorkee-247667, India',
#  'Information Security Institution|Sichuan University',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Department of Mechanical and Automation Engineering, The Chinese University of Hong Kong, Shatin, New Territories, Hong Kong',
#  'Orbital Sciences Corp./NASA Goddard Space Flight Center, Code 553, Greenbelt, MD 20771, USA',
#  'Department of Astronomy|University of Washington',
#  'NOAA|Forecast Systems Laboratory|Colorado State University',
#  'Stony Brook University',
#  'Department of Hematology/Oncology, University Hospital',
#  'University of Illinois Chicago',
#  'Siemens AG|Corporate Technology',
#  'De Montfort University',
#  'University of Illinois at Urbana-Champaign',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Microsoft, Redmond',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Department of Computer Science|University of Reading',
#  'Istituto di Ricerche Farmacologiche â€˜Mario Negriâ€™, Via La Masa 19, 20156 Milano, Italy',
#  'Universidad Nacional de Colombia Sede Manizales, Colombia',
#  'University of California , Los Angeles',
#  'Department of Sixties Science, Southern California Condominium College',
#  'Lawrence Berkeley National LaboratoryCenter for X-ray Optics|Lawrence Berkeley National Laboratory',
#  'Graduate School of Information|Production and Systems|Waseda University',
#  'Institute for Integrated Information and Publication Systems|German National Research Center for Information Technology',
#  'University of California Los Angeles',
#  'Department of Hematology, Erasmus Medical Center',
#  'Faculty of Pharmacy, Tehran University of Medical Sciences, Tehran, Iran',
#  'Department of Psychology|DÃ©partement de psychologie|University of Colorado at Boulder',
#  'Cardiology Division of Internal Medicine, Chungnam National University Hospital, Chungnam National University, Deajeon, Korea',
#  'Institute of Technology & Management Sect.23 Gurgaon India',
#  'Programa de Engenharia de Sistemas e ComputaÃ§Ã£o (COPPE), Universidade Federal do Rio de Janeiro Brazil',
#  'Materials Science and Engineering Program, University of Texas at Austin, Austin, Texas 78712',
#  'Department of Chemistry, Northern Illinois University, DeKalb, IL, 60115, U.S.A.',
#  'BerCom GmbH Bruno-Taut-Str. 4-6 D-12524 Berlin Germany Bruno-Taut-Str. 4-6 D-12524 Berlin Germany',
#  'Cardiology Division of Internal Medicine, Chungnam National University Hospital, Chungnam National University, Deajeon, Korea',
#  'Robert Bosch GmbH Hildesheim Germany Hildesheim Germany',
#  'Department of Computer Science|University of Wales',
#  'Heidelberg University',
#  'Department of Physics, University of California, Los Angeles, 405 Hilgard Ave., Los Angeles, CA 90024-1547 USA',
#  'Johns Hopkins University',
#  'Tel Aviv University and New York University',
#  'University College London',
#  'Lancaster University, United Kingdom',
#  'General Electric Company|Electronics Laboratory',
#  'Department of Experimental Hematology, Hannover Medical School',
#  'University of Wisconsin-Madison School of Pharmacy 53706 Madison Wisconsin 53706 Madison Wisconsin',
#  'University of Wisconsin-Madison School of Pharmacy 53706 Madison Wisconsin 53706 Madison Wisconsin',
#  'Department of Civil and Environmental Engineering, University of California, Berkeley, CA 94720, USA',
#  "Barrow Neurological Institute and St. Joseph's Hospital and Medical Center, Phoenix, AZ, USA",
#  'Key Laboratory of Vegetation Ecology, School of Life Sciences, Northeast Normal University, 130024 Changchun, China',
#  'Microsoft Research, Microsoft Corporation',
#  'Met Office Hadley Centre, Exeter, UK',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'Office of Naval Research',
#  'Technische UniversitÃ¤t Berlin, Institut fÃ¼r Atomare Physik und Fachdidaktik, Hardenbergstr. 36, 10623 Berlin, Germany DE',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Communication Technology|University of Wuppertal',
#  'University of California San Francisco',
#  'The french National Institute for Research in Computer science and Control',
#  'Universidad de las Islas Baleares Departamento de MatemÃ¡ticas e InformÃ¡tica Spain',
#  'Center for X-ray Optics|Lawrence Berkeley National Laboratory',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'Department of Mathematics, Nanjing University of Posts and Telecommunication, Nanjing 210003, China',
#  'Tsinghua University China',
#  'Japan Science and Technology',
#  'Kyoto University Graduate School of Informatics 606-8501 Japan',
#  'Department of Computer Science|University of Reading',
#  'Soonchunhyang University Bucheon Hospital, Bucheon, Korea',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Long-Term Capital Management',
#  'Universidad Carlos III de Madrid',
#  'Chonbuk National University Hospital, Jeonju, Korea',
#  'Department of Management Science, University of Vienna, Bruenner Strasse 72, A-1210 Vienna, Austria',
#  'Dpto. InformÃ¡tica y AutomÃ¡tica. Facultad de CC FÄ±Ì\x81sicas. U. Complutense. 28040 Madrid, Spain',
#  'Institut de recherche en informatique de Toulouse 118 route de Narbonne F-31062 Toulouse Cedex',
#  'Deutsche Telekom Berkom GmbH Berlin Germany Berlin Germany',
#  'IBM Austin Research Laboratory, Austin, TX 78758, USA',
#  'Department of Veterinary Medicine, Tulane National Primate Research Center, 18703 Three Rivers Road, Covington, LA 70433, USA',
#  'University of Washington',
#  'University of Pennsylvania|University of Pennsylvania|Purdue University',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Cardiology Division of Internal Medicine, Chungnam National University Hospital, Chungnam National University, Deajeon, Korea',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Pattern Recognition Group|Faculty of Applied Physics|Delft University of Technology',
#  'State Key Laboratory of Networking and Switching|Beijing University of Posts',
#  'Biochemisches Institut|Universit / it Freiburg',
#  'INAF-Osservatorio Astronomico di Capodimonte, Via Moiariello 16, I-80131 Napoli, Italy',
#  'Key Laboratory of Molecular Epigenetics of MOE, Northeast Normal University, 130024 Changchun, China',
#  'Japan Science and Technology',
#  'Hangzhou Dianzi University',
#  'Key Laboratory of Universal Wireless Communication|Beijing University of Posts and Telecommunications',
#  'Cairo Microsoft Innovation Lab',
#  'Jet Propulsion Laboratory, California Institute of Technology, 306-431, 4800 Oak Grove Drive, Pasadena, CA 91109 (United States)',
#  'Texas Tech University',
#  'Brain and Body Centre, University of Nottingham',
#  'Department of Materials Science and Engineering, University of Science and Technology of China, Anhui Hefei, P. R. China',
#  'CNRS and U 280 INSERM 151 Cours Albert Thomas 69300 Lyon France 151 Cours Albert Thomas 69300 Lyon France',
#  'School of Computer and Communication|Hunan University',
#  'Department of Materials Science and Engineering, University of Science and Technology of China, Anhui Hefei, P. R. China',
#  'School of Computer, National University of Defense Technology, Changsha, China',
#  'Department of Nuclear Engineering and Radiological Sciences, University of Michigan, Ann Arbor, MI 48109, USA',
#  'Universidad Politecnica de Valencia',
#  'Dept . of Economics|University of Bonn',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'University of Illinois at Urbana-Champaign',
#  'Materials Science and Engineering Program, University of Texas at Austin, Austin, Texas 78712',
#  'Department of Network Science, Graduate School of Information Systems, The University of Electro-Communications',
#  'Microsoft Research',
#  'Illinois Institute of Technology',
#  'Department of Chemistry, Wuhan University, Wuhan 430072, China',
#  'Lancaster University Lancaster Computing Department LA1 4YR UK',
#  'Swinburne University of Technology',
#  'Department of Geology and Geophysics, Yale University, PO Box 208109, New Haven, CT 06520-8109, USA',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'Electrical and Computer Engineering department at the University of Alabama at Birmingham, USA',
#  'College of Computing|Georgia Institute of Technology Atlanta',
#  'Institute for Integrated Information and Publication Systems|German National Research Center for Information TechnologyMicrosoft Research',
#  'Department of Computer Science and Technology|Tsinghua University',
#  'Key Laboratory of Vegetation Ecology, School of Life Sciences, Northeast Normal University, 130024 Changchun, China',
#  'University of Bremen',
#  'Soongsil University',
#  'State Key Laboratory for Advanced Metals and Materials, University of Science and Technology Beijing, Beijing 100083, PR China',
#  'Center for Wireless Communications',
#  'Artificial Intelligence Group, Faculty of Technology, Bielefeld University',
#  'Virginia Tech|Dept . of Computer Science',
#  'Atomic Energy Research Establishment, Harwell',
#  'Reproductive Ecology Laboratory, Department of Anthropology, Yale University, 51 Hillhouse Avenue, New Haven, CT 06520-8277, USA',
#  'Electrical and Computer Engineering department at the University of Alabama at Birmingham, USA',
#  'Information Security Institution|Sichuan University',
#  'Dept . of Physics',
#  'University of Pennsylvania|University of Pennsylvania|Purdue University',
#  'ETIS - UniversitÃ© de Cergy-Pontoise - ENSEA Neurocybernetics team 6, Av du Ponceau 95014 Cergy Pontoise Cedex France',
#  'National Institute of Standards and Technology',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Deutsche Telekom Berkom GmbH Berlin Germany Berlin Germany',
#  'Institute of Ion Beam Physics and Materials Research, FZR-Rossendorf, Dresden, Germany',
#  'Chair for Information Systems|Kassel University',
#  'Associated Laboratory of Plasma, National Institute for Space Research, S. J. Campos, S. Paulo, Brazil',
#  'Department of Nuclear Engineering and Radiological Sciences, University of Michigan, Ann Arbor, MI 48109, USA',
#  'Center for Cosmology and Particle Physics|Department of Physics|New York University',
#  'EOSTâ€“GÃ©ologie, universitÃ© Louis-Pasteur, 1, rue Blessig, 67084 Strasbourg cedex, France',
#  'Instituto Colombiano de GeologÃ\xada y MinerÃ\xada (Ingeominas), Colombia',
#  'Department of Computer Science|University of Reading',
#  'Leibniz Center for Tropical Marine Ecology, Fahrenheitstr. 6, 28359 Bremen, Germany',
#  'University of Karlsruhe Institut fÃ¼r Programmstrukturen und Datenorganisation D-76128 Karlsruhe Germany',
#  'INAF-Osservatorio Astronomico di Capodimonte, Via Moiariello 16, I-80131 Napoli, Italy',
#  'UNM/NSF Center for Micro-Engineered Ceramics, University of New Mexico, Albuquerque, NM 87131, USA',
#  'School of Computer and Communication|Hunan University',
#  'Institut fur Klinische Anaesthesiologie',
#  'Brain and Body Centre, University of Nottingham,UniversitÃ© de MontrÃ©al',
#  'Department of Physics, Faculty of Science and Engineering, Chuo University, Kasuga 1-13-27, Bunkyo-ku, Tokyo 112-8551 (Japan)',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'Montreal Neurological Institute, McGill University',
#  "UMR8022 Laboratoire d'Informatique Fondamentale de Lille",
#  'Institute for Cosmic Ray Research|University of Tokyo',
#  'German Aerospace Center, DLR Oberpfaffenhofen Germany Oberpfaffenhofen Germany',
#  'Department of Astronomy|University of Arizona',
#  'IBM Microelectronics, East Fishkill, NY 12533, USA',
#  'University of Pennsylvania|University of Pennsylvania|Purdue University',
#  'Department of Biomedical Engineering, Johns Hopkins University, Baltimore, MD 21218, USAJohns Hopkins University',
#  'Department of Hematology, Erasmus Medical Center',
#  'Microsoft Research',
#  'Department of Management Science, University of Vienna, Bruenner Strasse 72, A-1210 Vienna, Austria',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Department of Physics|University of Pennsylvania',
#  'Graduate School of Information|Production and Systems|Waseda University',
#  'Dept . of chemistry',
#  'University of Firenze Dipartimento di Matematica viale Morgagni, 67/a 50134 Firenze Italy',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Waseda UniversityGraduate School of Information|Production and Systems|Waseda University',
#  'Swiss Federal Institute of Technology ZurichHuman Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'CERN',
#  'Lorraine University â€“ Metz',
#  'Dept . of Speech Communication',
#  'Institut fÃ¼r Pharmakologie, Heinrich-Heine-UniversitÃ¤t DÃ¼sseldorf, DÃ¼sseldorf, Germany',
#  'National Institute of Standards and Technology',
#  'Programa de Engenharia de Sistemas e ComputaÃ§Ã£o (COPPE), Universidade Federal do Rio de Janeiro Brazil',
#  'IBM Microelectronics, East Fishkill, NY 12533, USA',
#  'Instituto de F Â´ Ãµsica Teorica',
#  'Institut fur Klinische Anaesthesiologie',
#  'Department of Psychiatry|Washington University|School of Medicine',
#  'Cairo Microsoft Innovation Lab',
#  'Texas Tech University',
#  'Stanford University',
#  'Center for Cosmology and Particle Physics|Department of Physics|New York University',
#  'Robert Bosch GmbH Hildesheim Germany Hildesheim Germany',
#  'Computer Science Department|University of California , Santa Cruz',
#  'Busan National University Hospital, Busan, Korea',
#  'Department of Chemistry, Wuhan University, Wuhan 430072, China',
#  'Coordinated Science Laboratory|Department of Electrical and Computer Engineering|University of Illinois at Urbana-Champaign',
#  'Information Security Institution|Sichuan University',
#  'INRIA Sophia Antipolis|University of Technology',
#  'Department of Physics, University of California, Los Angeles, 405 Hilgard Ave., Los Angeles, CA 90024-1547 USA',
#  'University of Tennessee-Atomic Energy Commission Agricultural Research Program, Oak Ridge, Tennessee',
#  'RMIT University, Melbourne, AustraliaSchool of Electrical and Computer Engineering, RMIT University, Melbourne, VIC 3001, Australia',
#  'San Raffaele Telethon Institute for Gene Therapy (HSR-TIGET),UniversitÃ\xa0 di Roma Tor Vergata',
#  'School of Computer, National University of Defense Technology, Changsha, China',
#  'Atomic Energy Research Establishment, Harwell',
#  'UniversitÃ© de MontrÃ©al,CEGEP Jonquiere',
#  'Department of Anthropology, Boston University, 232 Bay State Road, Boston, MA 02215, USA',
#  'University of Southern California',
#  'Pattern Recognition Lab, TU Delft, The Netherlands',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Department of Physical Metallurgy, The University, Birmingham',
#  'Department of Information Science|Nara Institute of Science and Technology',
#  'University of Tennessee-Atomic Energy Commission Agricultural Research Program, Oak Ridge, Tennessee',
#  "Division of Immunology/Hematology, University Children's Hospital",
#  'The University of Hong Kong Department of Mathematics Pokfulam Road Hong Kong',
#  'Department of Nuclear Engineering and Radiological Sciences, University of Michigan, Ann Arbor, MI 48109, USA',
#  'From the Pulvertaft Hand Centre, Derbyshire Royal Infirmary, Derby, UK',
#  'Kyushu University 812 Fukuoka Japan 812 Fukuoka Japan',
#  'Faculty of Pharmacy, Tehran University of Medical Sciences, Tehran, Iran',
#  'ETIS - UniversitÃ© de Cergy-Pontoise - ENSEA Neurocybernetics team 6, Av du Ponceau 95014 Cergy Pontoise Cedex France',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'Department of Computer Science, University of Sheffield, Sheffield S1 4DP, UK',
#  'Beihang University (Beijing University of Aeronautics and Astronautics)',
#  'Department of Materials Science and Engineering, University of Science and Technology of China, Anhui Hefei, P. R. China',
#  'Apache Point Observatory',
#  'Institute of Quartz and Special Glasses, China Building Materials Academy, Beijing 100024, PR China',
#  'University of California , Los Angeles',
#  'Department of Management Science, University of Vienna, Bruenner Strasse 72, A-1210 Vienna, Austria',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'National University of Singapore',
#  'ETIS - UniversitÃ© de Cergy-Pontoise - ENSEA Neurocybernetics team 6, Av du Ponceau 95014 Cergy Pontoise Cedex France',
#  'Dept . of Mech|Shiraz University',
#  'UniversitÃ© de MontrÃ©al',
#  'Nanjing Electronic Devices Institute 210016 Nanjing China',
#  'The University of Texas at Austin, Austin, TX 78712, USA',
#  'INRIA France',
#  'Seoul National University',
#  'Microsoft Research',
#  'ETIS - UniversitÃ© de Cergy-Pontoise - ENSEA Neurocybernetics team 6, Av du Ponceau 95014 Cergy Pontoise Cedex France',
#  'Saarland University',
#  'DISCA, Universidad PolitÃ©cnica de Valencia, Spain',
#  'NBER Contributor',
#  'Montreal Neurological Institute, McGill University',
#  'Institute of Technology & Management Sect.23 Gurgaon India',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Center for X-ray Optics|Lawrence Berkeley National Laboratory',
#  'Newborn Services, Royal Womenâ€™s Hospital, Melbourne, Victoria, Australia',
#  'IIT unit of Molecular Neuroscience, Instituto Scientifico H. San Raffaele',
#  'Microsoft Research',
#  'Department of Computer Science|University of Wales',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  "Ashoka's Changemakers",
#  'School of Computer, National University of Defense Technology, Changsha, China',
#  'Department of Informatics, Faculty of Sciences, University of Lisbon, Campo Grande, 1749-016 Lisboa, Portugal',
#  'Biochemisches Institut|Universit / it Freiburg',
#  'Cardiology Division of Internal Medicine, Chungnam National University Hospital, Chungnam National University, Deajeon, Korea',
#  'Nanjing Electronic Devices Institute 210016 Nanjing China',
#  'Japan Science and Technology',
#  'Seoul National University',
#  'University of Savoie, France',
#  'Neuroradiology Division, Phipps B100, Radiology and Radiological Science, Johns Hopkins University, Baltimore, MD 21287, USA',
#  "Istituto Matematico dell'UniversitÃ\xa0 di Genova Switzerland",
#  'University of Tennessee-Atomic Energy Commission Agricultural Research Program, Oak Ridge, Tennessee',
#  'Southeast University Department of Instrument Science and Engineering 210096 Nanjing China',
#  'Department of Electrical and Computer Engineering|University of Alberta',
#  'Department of Automation, College of Information Engineering, Yangzhou University, Yangzhou, 225009 China',
#  'University of California , Los Angeles',
#  'IBM T. J. Watson Research Center',
#  'Princeton University',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Chonbuk National University Hospital, Jeonju, Korea',
#  'Brain and Body Centre, University of Nottingham',
#  'Electrical and Computer Engineering department at the University of Alabama at Birmingham, USA',
#  'Microsoft Research',
#  'Universidad Carlos III de Madrid',
#  'Technische UniversitÃ¤t Berlin, Institut fÃ¼r Atomare Physik und Fachdidaktik, Hardenbergstr. 36, 10623 Berlin, Germany DE',
#  'IBM',
#  'University of Chicago',
#  'Department of Veterinary Medicine, Tulane National Primate Research Center, 18703 Three Rivers Road, Covington, LA 70433, USA',
#  'College of Computing|Georgia Institute of Technology Atlanta',
#  'Singapore Membrane Technology Centre, Nanyang Technological University, Singapore 639798, Singapore',
#  'Fermi National Laboratory',
#  'Soonchunhyang University Bucheon Hospital, Bucheon, Korea',
#  'Newborn Services, Royal Womenâ€™s Hospital, Melbourne, Victoria, Australia',
#  'University of Wisconsin-Madison School of Pharmacy 53706 Madison Wisconsin 53706 Madison Wisconsin',
#  'Universitat PolitÃ¨cnica de CatalunyaALBCOM, Dept. Llenguatges i Sistemes InformÃ\xa0tics, Universitat PolitÃ¨cnica de Catalunya, E-08034 Barcelona, Spain',
#  'State Key Laboratory for Advanced Metals and Materials, University of Science and Technology Beijing, Beijing 100083, PR China',
#  'Key Laboratory of Vegetation Ecology, School of Life Sciences, Northeast Normal University, 130024 Changchun, China',
#  'Dpto. InformÃ¡tica y AutomÃ¡tica. Facultad de CC FÄ±Ì\x81sicas. U. Complutense. 28040 Madrid, Spain',
#  'Department of Biomedical Engineering, Johns Hopkins University, Baltimore, MD 21218, USA',
#  'Department of Computer Science|University of Wales',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Mayo Clinic, Rochester, MN, USA',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'Princeton University',
#  'Department of Computer Science, University of Leicester, University Road, Leicester, LE1 7RH UK',
#  'Center for Wireless Communications',
#  'Department of Hematology/Oncology, University Hospital',
#  'National Taiwan University',
#  'Laboratory of Neurosciences, National Institute on Aging, Intramural Research Program, Baltimore, MD, USA',
#  'CERN',
#  'Molecular Immunology Unit, Institute of Child Health, University College',
#  'Cairo Microsoft Innovation Lab',
#  'Nokia Research Centre c/o Nanoscience Centre, University of Cambridge, 11 JJ Thomson Av., CB3 0FF, Cambridge, UK',
#  'St Josephs College',
#  'UniversitÃ\xa0 Parthenope Via A. De Gasperi 5, I-80133 Napoli, Italy',
#  'University of California , Los Angeles',
#  'Chair for Information Systems|Kassel University',
#  'Advanced Technologies Application Center (Cenatav), Cuba',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'NBER Contributor',
#  'State Key Laboratory for Powder Metallurgy, Central South University, Changsha 410083, PR China',
#  'Beihang University (Beijing University of Aeronautics and Astronautics)',
#  'Center for X-ray Optics|Lawrence Berkeley National Laboratory',
#  'Department of Electrical Engineering, University of Tokyo, Japan',
#  'Department of Psychology|DÃ©partement de psychologie|University of Colorado at Boulder',
#  'From the Pulvertaft Hand Centre, Derbyshire Royal Infirmary, Derby, UK',
#  'Department of Network Science, Graduate School of Information Systems, The University of Electro-Communications',
#  'Department of Physics, University of California, Los Angeles, 405 Hilgard Ave., Los Angeles, CA 90024-1547 USA',
#  'University of Central Florida',
#  'Faculty of Pharmacy, Tehran University of Medical Sciences, Tehran, Iran',
#  'Consiglio Nazionale delle Ricerche - Istituto per lo Studio degli Ecosistemi',
#  'School of Computer, National University of Defense Technology, Changsha, China',
#  'Department of Computer Science, University of Leicester, University Road, Leicester, LE1 7RH UK',
#  'National University of Singapore',
#  'Cairo Microsoft Innovation Lab',
#  'Department of Translational Oncology, National Center for Tumor Diseases and German Cancer Research Center (DKFZ)',
#  'Department of Computer Science; Michigan State University',
#  'UniversitÃ¤t TÃ¼bingen Wilhelm-Schickard-Institut fÃ¼r Informatik D-72076 T Ã¼bingen Germany',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'Department of Chemistry, Wuhan University, Wuhan 430072, China',
#  'German Aerospace Center, DLR Oberpfaffenhofen Germany Oberpfaffenhofen Germany',
#  'Institute for Biomedical Research, Georg-Speyer-Haus',
#  'Department of Biological Science|Nara Institute of Science and Technology',
#  'UNM/NSF Center for Micro-Engineered Ceramics, University of New Mexico, Albuquerque, NM 87131, USA',
#  'Microsoft Research',
#  'Brain and Body Centre, University of Nottingham,Montreal Neurological Institute, McGill University',
#  'School of Computer, National University of Defense Technology, Changsha, China',
#  'UniversitÃ\xa0 Parthenope Via A. De Gasperi 5, I-80133 Napoli, Italy',
#  'SeÃ§Ã£o de Engenharia de Sistemas, Instituto Militar de Engenharia Brazil',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'Princeton UniversityPrinceton University',
#  'Institute of Computing Technology, Chinese Academy of Sciences, China',
#  'Computer Science Department|University of California , Santa CruzUniversity of California Santa Cruz',
#  'College of Computing|Georgia Institute of Technology Atlanta',
#  'School of Computer and Communication|Hunan University',
#  'Departamento MatemÃ¡tica, FCEyN UBA (1428) Buenos Aires, Argentina',
#  'Nanjing Electronic Devices Institute 210016 Nanjing China',
#  'National Climatic Data Center, NOAA, Asheville, North Carolina, USA',
#  "Istituto Matematico dell'UniversitÃ\xa0 di Genova Switzerland",
#  'Key Laboratory of Vegetation Ecology, School of Life Sciences, Northeast Normal University, 130024 Changchun, China',
#  'UniversitÃ\xa0 degli Studi di Roma La Sapienza',
#  'Lancaster University Lancaster Computing Department LA1 4YR UK',
#  "MusÃ©um National d'Histoire NaturelleEntomologie, CNRS UMR 5143, MusÃ©um national d'histoire naturelle, 45, rue Buffon, 75005 Paris, France",
#  'Institute of Computing Technology, Chinese Academy of Sciences, China',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Department of Animal and Plant Sciences, University of Sheffield, Sheffield S1 4DP, UK',
#  'Singapore Membrane Technology Centre, Nanyang Technological University, Singapore 639798, Singapore',
#  'From the Pulvertaft Hand Centre, Derbyshire Royal Infirmary, Derby, UK',
#  'Inorganic Materials Research Program|School of Physical and Chemical Sciences|Queensland University of Technology',
#  'Departamento de InformÃ¡tica., Universidad de Valencia, Spain',
#  'Center for Theoretical Physics, Sloane Physics Lab, Yale University, New Haven, CT 06520-8120, USA',
#  'State Key Laboratory of Networking and Switching|Beijing University of Posts',
#  'Rheumatology Department and Northern Clinical School, Royal North Shore Hospital',
#  'Department of Network Science, Graduate School of Information Systems, The University of Electro-Communications',
#  'Department of Psychology, University of Quebec in Chicoutimi',
#  'Busan National University Hospital, Busan, Korea',
#  'DuPont Co., Experimental Station 356/384, Wilmington, DE 19880, USA',
#  'Stanford UniversityComputer Science Department|Stanford University',
#  'Departments of Radiology, Medicine, and Psychiatry, University of California, San Francisco, San Francisco, CA, USA',
#  'Department of Materials Science and Metallurgy, University of Cambridge, UK',
#  'Center for Artificial Intelligence Research|Computer Science Department|Korea Advanced Institute of Science & Technology',
#  'Hallym University Sacred Heart Hospital, Anyang, Korea.',
#  'Virginia Tech|Dept . of Computer Science',
#  'Institut fur Klinische Anaesthesiologie',
#  'The University of Texas at Austin, Austin, TX 78712, USA',
#  'Institut fur Klinische Anaesthesiologie',
#  'Department of Materials Science and Engineering, University of Science and Technology of China, Anhui Hefei, P. R. China',
#  'Swiss Federal Institute of Technology Zurich',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Computer Science Department; Michigan State University',
#  'Faculty of Pharmacy, Tehran University of Medical Sciences, Tehran, Iran',
#  'Dept. of Computer Science, Columbia University, USA',
#  'Department of Physics, University of California, Los Angeles, 405 Hilgard Ave., Los Angeles, CA 90024-1547 USA',
#  'Department of Management Science, University of Vienna, Bruenner Strasse 72, A-1210 Vienna, Austria',
#  'Virginia Tech|Dept . of Computer Science',
#  'Inorganic Materials Research Program|School of Physical and Chemical Sciences|Queensland University of Technology',
#  'Microsoft Research',
#  'Merck Research Laboratories P.O. Box 4/WP26-462 West Point PA 19486 USA',
#  'NOAA Forecast Systems Laboratory',
#  'Royal Institute of Technology',
#  'Academy of Mathematics and System Sciences CAS',
#  'Princeton University',
#  'The University of Texas at Austin Department of Computer Sciences USA USA',
#  'From the Pulvertaft Hand Centre, Derbyshire Royal Infirmary, Derby, UK',
#  'Chair for Information Systems|Kassel University',
#  'Microsoft',
#  'Department of Physics, Federal University of ParanÃ¡, Curitiba, Brazil',
#  'From the Pulvertaft Hand Centre, Derbyshire Royal Infirmary, Derby, UK',
#  'Princeton University',
#  'U. S. Naval Observatory',
#  'Hematology Branch, National Heart, Lung and Blood Institute',
#  'Center for X-ray Optics|Lawrence Berkeley National Laboratory',
#  'Department of Information Science|Nara Institute of Science and Technology',
#  'Cardiology Division of Internal Medicine, Chungnam National University Hospital, Chungnam National University, Deajeon, Korea',
#  'Maastricht University',
#  'Southeast University Department of Instrument Science and Engineering 210096 Nanjing China',
#  'Department of Chemistry, Wuhan University, Wuhan 430072, China',
#  'Dept. of Physics, Keio University, 4-1-1 Hiyoshi, Kouhoku-ku, Yokohama 223-8521, Japan',
#  'Computer Science Department|University of California , Santa Cruz',
#  'Department of Computer Science',
#  'IBM Austin Research Laboratory, Austin, TX 78758, USA',
#  'Associated Laboratory of Plasma, National Institute for Space Research, S. J. Campos, S. Paulo, Brazil',
#  'Information and Computer Science Department at the University of California, Irvine.',
#  'Department of Nuclear Engineering and Radiological Sciences, University of Michigan, Ann Arbor, MI 48109, USA',
#  'Department of Metallurgy, The University, Liverpool',
#  'Princeton University',
#  'Dept . of Mech|Shiraz University',
#  'Department of Astronomy|Pennsylvania State University',
#  'Center for Artificial Intelligence Research|Computer Science Department|Korea Advanced Institute of Science & Technology',
#  'INAF-Osservatorio Astronomico di Capodimonte, Via Moiariello 16, I-80131 Napoli, Italy',
#  'University of Belgrade, Institute of Chemistry, Technology and MetallurgyUniversity of Belgrade Institute of electrochemistry ICTM Karnegijeva 4 11000 Belgrade Yugoslavia',
#  'Sharif University of Technology',
#  'University of Ontario Institute of Technology',
#  'Universidad de Puerto Rico',
#  'Key Laboratory of Vegetation Ecology, School of Life Sciences, Northeast Normal University, 130024 Changchun, China',
#  'National Taiwan University',
#  'Departamento de MatemÃ¡ticas, U. AutÃ³noma de Madrid, 28049 Madrid, Spain',
#  'University of TokyoDepartment of Network Science, Graduate School of Information Systems, The University of Electro-Communications',
#  'University of Belgrade, Forestry faculty Department of Wood Science and Technology Kneza ViÅ¡eslava 1 11030 Belgrade Yugoslavia',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'University of Tennessee-Atomic Energy Commission Agricultural Research Program, Oak Ridge, Tennessee',
#  'Centro de InvestigaciÃ³n y Docencia EconÃ³micas',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'CertCo, New York, NY, USA',
#  'Microsoft',
#  'Dept . of Speech Communication',
#  'Department of Electrical and Computer Engineering|University of Alberta',
#  'Met Office Hadley Centre, Exeter, UK',
#  'University of Cambridge',
#  'Climatic Research Unit, School of Environmental Sciences, University of East Anglia, Norwich, UK',
#  'Deutsche Thomson Brandt GmbH Hanover Germany Hanover Germany',
#  'Information Security Institution|Sichuan University',
#  'Nanjing University',
#  'INRIA Sophia Antipolis|University of Technology',
#  'Institute of Quartz and Special Glasses, China Building Materials Academy, Beijing 100024, PR China',
#  'Advanced Technologies Application Center (Cenatav), Cuba',
#  'Chair for Information Systems|Kassel University',
#  'Human Computer Interaction Institute and Institute for Complex Engineered Systems|Carnegie Mellon University',
#  'Institut fur Klinische Anaesthesiologie',
#  'University of Belgrade, Forestry faculty Department of Wood Science and Technology Kneza ViÅ¡eslava 1 11030 Belgrade Yugoslavia',
#  'UniversitÃ© de MontrÃ©al,CEGEP Jonquiere',
#  'Massachusetts Institute of Technology',
#  'Institute of Computing Technology, Chinese Academy of Sciences, China',
#  'University of Belgrade, Forestry faculty Department of Wood Science and Technology Kneza ViÅ¡eslava 1 11030 Belgrade Yugoslavia',
#  'Institut Neurosciences et ModÃ©lisation Paris VI',
#  'Department of Computer Science, University of Sheffield, Sheffield S1 4DP, UK',
#  'ALBCOM, Dept. Llenguatges i Sistemes InformÃ\xa0tics, Universitat PolitÃ¨cnica de Catalunya, E-08034 Barcelona, Spain',
#  'Faculty of Pharmacy, Tehran University of Medical Sciences, Tehran, Iran',
#  'Department of Hematology, Erasmus Medical Center,Department of Experimental Hematology, Hannover Medical School',
#  'Coordinated Science Laboratory|University of Illinois at Urbana-Champaign',
#  'Department of Chemistry, Wuhan University, Wuhan 430072, China',
#  'Biochemisches Institut|Universit / it Freiburg',
#  'Asan Medical Center, University of Ulsan College of Medicine, Seoul, Korea',
#  'Department of Community Health|University of Auckland',
#  'State Key Laboratory of Networking and Switching|Beijing University of Posts',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA',
#  'Department of Computer Science|University of Regina',
#  'University of Oregon',
#  'Information Security Institution|Sichuan University',
#  'Departamento de InformÃ¡tica., Universidad de Valencia, Spain',
#  'Department of Mechanical Engineering, Technological Institute of Aeronautics, S. J. Campos, S. Paulo, Brazil',
#  'Tohoku University',
#  'Dept . of Physics',
#  'Department of Physics, Federal University of ParanÃ¡, Curitiba, Brazil',
#  'Dept . of Mech|Shiraz University',
#  'Department of Nuclear Engineering and Radiological Sciences, University of Michigan, Ann Arbor, MI 48109, USA',
#  'San Raffaele Telethon Institute for Gene Therapy (HSR-TIGET)',
#  'German Aerospace Center, DLR Oberpfaffenhofen Germany Oberpfaffenhofen Germany',
#  'Departamento de InformÃ¡tica., Universidad de Valencia, Spain',
#  'Institute of Technology & Management Sect.23 Gurgaon India',
#  'Laboratory of Neuro Imaging, Department of Neurology, UCLA School of Medicine, Los Angeles, CA, USA']

# %%
list(pa.index())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-2ecf88a1e585> in <module>()
# ----> 1 list(pa.index())
#
# TypeError: 'RangeIndex' object is not callable

# %%
dict_paper = paper_keywords(dataset)
# Out:
# Start title!!!
# Start keyword!!!
# Start concatenation!!!

# %%
dict_paper
# Out:
# defaultdict(list,
#             {1: ['mobil',
#               'video',
#               'captur',
#               'real',
#               'time',
#               'video',
#               'stitch',
#               'stitch',
#               'video',
#               'stream',
#               'mobil',
#               'phone'],
#              2: ['nonloc',
#               'diffus',
#               'asymptot',
#               'behaviour',
#               'nonloc',
#               'equat'],
#              3: ['area', 'effect', 'cepaea'],
#              4: ['multipl',
#               'patern',
#               'natur',
#               'popul',
#               'salamand',
#               'sperm',
#               'storag'],
#              5: ['complex', 'find', 'short', 'resolut', 'proof'],
#              6: ['softwar',
#               'system',
#               'larg',
#               'dynam',
#               'map',
#               'base',
#               'network',
#               'geograph',
#               'databas'],
#              7: ['natur', 'histori', 'psychoneuros'],
#              8: ['growth',
#               'hormon',
#               'receptor',
#               'onset',
#               'hyperinsulinemia',
#               'obes',
#               'zucker',
#               'rat'],
#              9: ['methyl',
#               'epigenet',
#               'metastasi',
#               'promot',
#               'colon',
#               'cancer',
#               'hypermethyl',
#               'gene',
#               'primari',
#               'metastat',
#               'colorect',
#               'cancer'],
#              10: ['ruc', 'ensembl', 'forecast', 'system'],
#              11: ['formal', 'approach', 'servic', 'compon', 'architectur'],
#              12: ['fiber', 'gener', 'framework', 'softwar'],
#              13: ['model', 'verifi', 'broad', 'array', 'network', 'properti'],
#              14: ['monitor',
#               'nitrat',
#               'variat',
#               'typic',
#               'subterranean',
#               'karst',
#               'stream',
#               'chongq',
#               'china'],
#              15: ['data',
#               'object',
#               'creation',
#               'display',
#               'techniqu',
#               'huge',
#               'databas',
#               'subscrib',
#               'cabl',
#               'network'],
#              16: ['precondition', 'system', 'ode', 'code'],
#              17: ['framework', 'parallel', 'process', 'datalog', 'queri'],
#              18: ['synthesi',
#               'endomorph',
#               'model',
#               'event',
#               'base',
#               'intellig',
#               'control',
#               'employ',
#               'combin',
#               'simul'],
#              19: ['automata'],
#              20: ['googlemetri', 'und', 'arbeitsmarkt'],
#              21: ['combin',
#               'laparoscop',
#               'thoracoscop',
#               'approach',
#               'esophagectomi'],
#              22: ['optim', 'wage', 'incom', 'taxat', 'wage', 'uncertainti'],
#              23: ['univers',
#               'class',
#               'spread',
#               'phenomena',
#               'new',
#               'model',
#               'fix',
#               'static',
#               'continu',
#               'tunabl',
#               'kinet',
#               'expon'],
#              24: ['augment',
#               'equival',
#               'principl',
#               'algorithm',
#               'low',
#               'frequenc'],
#              25: ['languag', 'model', 'need', 'agreement', 'constraint'],
#              26: ['potenti',
#               'effect',
#               'stimuli',
#               'mechan',
#               'nucleu',
#               'accumben'],
#              27: ['use', 'reactiv', 'adapt', 'behavior', 'play', 'soccer'],
#              28: ['system', 'part', 'km'],
#              29: ['newer',
#               'approach',
#               'diagnosi',
#               'earli',
#               'onset',
#               'neonat',
#               'sepsi'],
#              30: ['epilog'],
#              31: ['subcellular', 'local', 'nucleas', 'barley', 'aleuron'],
#              32: ['für', 'heterogen', 'computernetzwerk'],
#              33: ['fluid', 'queue', 'regular', 'variat'],
#              34: ['interdomain', 'rout', 'linear', 'util'],
#              35: ['venu',
#               'atmospher',
#               'wave',
#               'challeng',
#               'nonlinear',
#               'dynam'],
#              36: ['biomark', 'senesc', 'male', 'primat'],
#              37: [],
#              38: ['cheddar', 'chees', 'manufactur', 'condens'],
#              39: ['identif',
#               'mesoderm',
#               'develop',
#               'mesd',
#               'candid',
#               'gene',
#               'compar',
#               'map',
#               'genom',
#               'sequenc',
#               'analysi'],
#              40: ['optic',
#               'properti',
#               'organ',
#               'materi',
#               'polar',
#               'sensit',
#               'devic',
#               'terahertz',
#               'birefring',
#               'attenu',
#               'properti',
#               'wood',
#               'paper'],
#              41: ['random',
#               'comparison',
#               'versu',
#               'stent',
#               'implant',
#               'patient',
#               'diabet',
#               'mellitu'],
#              42: ['studi', 'cmo', 'protect', 'circuit', 'use', 'simul'],
#              43: ['control',
#               'volum',
#               'mesh',
#               'use',
#               'sphere',
#               'pack',
#               'gener',
#               'refin',
#               'coarsen'],
#              44: ['facilit',
#               'access',
#               'point',
#               'select',
#               'ieee',
#               'wireless',
#               'network'],
#              45: ['educ', 'democraci', 'growth'],
#              46: ['highli',
#               'porou',
#               'spongelik',
#               'ceram',
#               'film',
#               'bimod',
#               'pore',
#               'structur',
#               'prepar',
#               'electrostat',
#               'spray',
#               'deposit',
#               'techniqu'],
#              47: [],
#              48: ['prove', 'commit', 'number', 'prime'],
#              49: ['anatom',
#               'analysi',
#               'development',
#               'effect',
#               'aneuploidi',
#               'man',
#               'syndrom'],
#              50: ['chemiluminesc',
#               'anod',
#               'etch',
#               'silicon',
#               'evid',
#               'luminesc',
#               'layer',
#               'porou',
#               'silicon'],
#              51: ['comput',
#               'model',
#               'x',
#               'machin',
#               'ant',
#               'forag',
#               'pattern',
#               'pheromon',
#               'self',
#               'organis',
#               'system',
#               'coupl',
#               'comput',
#               'simul',
#               'empir',
#               'research',
#               'forag',
#               'system',
#               'ant',
#               'monomorium',
#               'pharaoni'],
#              52: ['residu', 'magnet', 'mri', 'suit', 'issu', 'experi'],
#              53: ['complex',
#               'network',
#               'slide',
#               'mode',
#               'smart',
#               'control',
#               'synchron',
#               'weight',
#               'small',
#               'world',
#               'complex',
#               'network',
#               'smart',
#               'slide',
#               'mode',
#               'control'],
#              54: ['linear',
#               'frequenc',
#               'resolv',
#               'optic',
#               'gate',
#               'line',
#               'monitor',
#               'tool'],
#              55: ['bound', 'dynam', 'circuit'],
#              56: ['eleonora',
#               'aleksandrovna',
#               'storozhenko',
#               'sixtieth',
#               'birthday'],
#              57: ['banner',
#               'advertis',
#               'world',
#               'wide',
#               'web',
#               'adapt',
#               'adapt',
#               'configur',
#               'user',
#               'model',
#               'user',
#               'profil',
#               'pull',
#               'strategi',
#               'advertis',
#               'profil',
#               'appli',
#               'web',
#               'page',
#               'banner'],
#              58: ['nanomet', 'calibr', 'particl', 'avail', 'need'],
#              59: ['canopi',
#               'develop',
#               'grain',
#               'legum',
#               'grown',
#               'differ',
#               'soil',
#               'water',
#               'regim',
#               'tropic',
#               'environ'],
#              60: ['capabl',
#               'approach',
#               'entrepreneurship',
#               'human',
#               'develop',
#               'entrepreneurship',
#               'human',
#               'develop',
#               'capabl',
#               'approach'],
#              61: ['featur',
#               'likelihood',
#               'map',
#               'direct',
#               'evalu',
#               'object',
#               'hypothes'],
#              62: ['induct',
#               'mix',
#               'chimer',
#               'transplant',
#               'toler',
#               'primat',
#               'lung',
#               'allograft',
#               'model',
#               'earli',
#               'result'],
#              63: ['eectiv',
#               'check',
#               'disprov',
#               'finit',
#               'variant',
#               'properti'],
#              64: ['delay',
#               'transistor',
#               'logic',
#               'gate',
#               'cost',
#               'function',
#               'sensit',
#               'lithographi',
#               'coupl',
#               'time',
#               'object',
#               'optic',
#               'proxim',
#               'correct',
#               'improv',
#               'time',
#               'yield'],
#              65: [],
#              66: ['et', 'al', 'scientif', 'method', 'social', 'chang'],
#              67: ['invers', 'dispers', 'data', 'applic', 'borehol', 'acoust'],
#              68: ['incident',
#               'posit',
#               'intern',
#               'mammari',
#               'lymph',
#               'node',
#               'multipl',
#               'intern',
#               'institut',
#               'investig'],
#              69: ['tradeoff',
#               'buffer',
#               'memori',
#               'state',
#               'specul',
#               'multiprocessor'],
#              70: ['algebra', 'foundat', 'diagram', 'comput'],
#              71: ['famili',
#               'simpl',
#               'hypohidrosi',
#               'abnorm',
#               'palmar',
#               'dermal',
#               'ridg'],
#              72: ['ergod',
#               'arithmet',
#               'properti',
#               'geometr',
#               'progress',
#               'dynam',
#               'orbit'],
#              73: ['distribut', 'coordin', 'algorithm', 'multipl', 'system'],
#              74: ['lei',
#               'de',
#               'beer',
#               'aplicada',
#               'na',
#               'atmosfera',
#               'terrestr'],
#              75: ['neutrophil',
#               'macrophag',
#               'inflammatori',
#               'protein',
#               'chemotaxi',
#               'dendrit',
#               'cell',
#               'laminin',
#               'neutrophil',
#               'secret',
#               'adhes',
#               'laminin',
#               'contain',
#               'basement',
#               'membran',
#               'blood',
#               'vessel'],
#              76: ['graphic',
#               'hardwar',
#               'imag',
#               'reconstruct',
#               'tomographi',
#               'acceler',
#               'popular',
#               'tomograph',
#               'reconstruct',
#               'algorithm',
#               'commod',
#               'pc',
#               'graphic',
#               'hardwar'],
#              77: ['direct',
#               'laser',
#               'beam',
#               'write',
#               'ybacuo',
#               'film',
#               'superconduct',
#               'microelectron',
#               'devic'],
#              78: ['public',
#               'good',
#               'experi',
#               'social',
#               'prefer',
#               'condit',
#               'cooper',
#               'free',
#               'ride',
#               'social',
#               'prefer',
#               'belief',
#               'dynam',
#               'free',
#               'ride',
#               'public',
#               'good',
#               'experi'],
#              79: ['convers',
#               'point',
#               'gestur',
#               'virtual',
#               'realiti',
#               'interact',
#               'implic',
#               'empir',
#               'studi'],
#              80: ['equat', 'solv', 'geometr', 'theori'],
#              81: ['determin',
#               'planetari',
#               'meteorolog',
#               'aerobot',
#               'flight',
#               'sensor'],
#              82: ['effici', 'filter', 'find', 'given', 'length'],
#              83: ['infrar',
#               'star',
#               'star',
#               'format',
#               'star',
#               'pre',
#               'main',
#               'sequenc',
#               'x',
#               'ray',
#               'star',
#               'power',
#               'sourc',
#               'cepheu',
#               'region'],
#              84: ['physic',
#               'activ',
#               'function',
#               'capac',
#               'measur',
#               'women',
#               'report',
#               'wise',
#               'studi'],
#              85: ['open',
#               'sourc',
#               'social',
#               'solut',
#               'build',
#               'commun',
#               'chang'],
#              86: ['permien',
#               'tria',
#               'insect',
#               'archaeorthoptera',
#               'odonatoptera',
#               'extinct',
#               'radiat',
#               'triassic',
#               'radiat',
#               'entomofauna'],
#              87: ['key',
#               'word',
#               'houttuynia',
#               'saururacea',
#               'essenti',
#               'oil',
#               'antibacteri',
#               'gc',
#               'ms',
#               'chemic',
#               'compon',
#               'variat',
#               'chemic',
#               'composit',
#               'antibacteri',
#               'activ',
#               'essenti',
#               'oil',
#               'two',
#               'speci',
#               'houttuynia',
#               'thunb'],
#              88: ['chapter', 'human', 'health', 'aspect'],
#              89: ['gprobot', 'gpteam', 'competit', 'genet', 'program'],
#              90: ['radiocarbon', 'date', 'la', 'venta', 'tabasco'],
#              91: ['une',
#               'généralis',
#               'de',
#               'la',
#               'théori',
#               'de',
#               'type',
#               'en',
#               'premièr',
#               'parti'],
#              92: ['boolean',
#               'classier',
#               'gener',
#               'boolean',
#               'classic',
#               'rule'],
#              93: ['polysiloxan',
#               'synthesi',
#               'indol',
#               'synthesi',
#               'novel',
#               'poli',
#               'propyl',
#               'siloxan',
#               'nonlinear',
#               'optic',
#               'polym',
#               'via',
#               'postfunction'],
#              94: ['neuroprotect',
#               'calori',
#               'restrict',
#               'ketogen',
#               'diet',
#               'keton',
#               'bodi',
#               'oxid',
#               'stress',
#               'mitochondria',
#               'brain',
#               'neuroprotect',
#               'properti',
#               'calori',
#               'restrict',
#               'ketogen',
#               'diet',
#               'keton',
#               'bodi'],
#              95: ['alkalin',
#               'phosphatas',
#               'activ',
#               'freshwat',
#               'spring',
#               'phytoplankton',
#               'applic',
#               'novel',
#               'method'],
#              96: [],
#              97: ['rubl', 'overhang', 'rubl', 'shortag', 'thing'],
#              98: ['aspect',
#               'composit',
#               'appli',
#               'design',
#               'contract',
#               'principl'],
#              99: ['key',
#               'word',
#               'chorion',
#               'type',
#               'later',
#               'motor',
#               'skill',
#               'twin',
#               'manual',
#               'perform',
#               'later',
#               'twin',
#               'known',
#               'chorion',
#               'type'],
#              100: ['set', 'postul', 'field'],
#              101: [],
#              102: [],
#              103: ['vacanc', 'trap', 'quench', 'aluminium', 'alloy'],
#              104: [],
#              105: ['method', 'unif', 'uml', 'oml'],
#              106: ['code',
#               'noisi',
#               'binari',
#               'imag',
#               'use',
#               'statist',
#               'morpholog',
#               'skeleton'],
#              107: ['antpack',
#               'ant',
#               'coloni',
#               'optim',
#               'approach',
#               'bin',
#               'pack',
#               'problem'],
#              108: ['activ',
#               'learn',
#               'via',
#               'transduct',
#               'experiment',
#               'design'],
#              109: ['corrigendum',
#               'leudesdorf',
#               'extens',
#               'wolstenholm',
#               'theorem'],
#              110: ['domain',
#               'structur',
#               'hysteresi',
#               'dielectr',
#               'loss',
#               'and',
#               'relax',
#               'piezoelectr',
#               'and',
#               'electromechan',
#               'effect',
#               'crystallin',
#               'state',
#               'crystallograph',
#               'depend',
#               'loss',
#               'domain',
#               'engin',
#               'singl',
#               'crystal'],
#              111: ['posit',
#               'control',
#               'platform',
#               'use',
#               'invers',
#               'dynam',
#               'method',
#               'full',
#               'dynam'],
#              112: ['perform', 'system', 'mobil', 'environ'],
#              113: ['princip',
#               'compon',
#               'iter',
#               'regress',
#               'analysi',
#               'geophys',
#               'seri',
#               'applic',
#               'sunspot',
#               'number'],
#              114: ['telework', 'experi', 'japan'],
#              115: ['toward', 'loos', 'coupl', 'program', 'petascal', 'system'],
#              116: ['comput', 'complex', 'xor', 'problem'],
#              117: ['cluster', 'sequenc', 'hidden', 'markov', 'model'],
#              118: [],
#              119: ['role',
#               'plasma',
#               'free',
#               'fatti',
#               'acid',
#               'develop',
#               'fatti',
#               'liver'],
#              120: ['converg', 'rate', 'approxim', 'translat'],
#              121: ['structur',
#               'correl',
#               'ionotrop',
#               'glutam',
#               'receptor',
#               'function'],
#              122: ['race',
#               'model',
#               'perceptu',
#               'forc',
#               'choic',
#               'reaction',
#               'time'],
#              123: ['gene',
#               'encod',
#               'put',
#               'acid',
#               'synthas',
#               'glarea',
#               'lozoyensi'],
#              124: ['simpl',
#               'algorithm',
#               'cellular',
#               'system',
#               'fade',
#               'environ'],
#              125: ['biomimet', 'reaction', 'oxygen', 'oxygen'],
#              126: ['robust',
#               'handwritten',
#               'word',
#               'recognit',
#               'fuzzi',
#               'set'],
#              127: [],
#              128: ['ein',
#               'haufen',
#               'stein',
#               'macht',
#               'noch',
#               'lang',
#               'kein',
#               'gebäud',
#               'da',
#               'internet',
#               'projekt',
#               'bine',
#               'der',
#               'stadtbibliothek',
#               'bremen'],
#              129: ['pulmonari',
#               'metastas',
#               'primari',
#               'hepatocellular',
#               'carcinoma',
#               'patient',
#               'case',
#               'report'],
#              130: ['studi',
#               'classif',
#               'micrograph',
#               'base',
#               'svm',
#               'studi',
#               'classif',
#               'micrograph',
#               'base',
#               'svm'],
#              131: [],
#              132: ['recognit', 'lumbar', 'disk', 'herniat', 'nmr'],
#              133: ['character', 'distribut', 'virtual', 'environ', 'system'],
#              134: ['lutetium',
#               'crown',
#               'ether',
#               'structur',
#               'x',
#               'ray',
#               'hydrogen',
#               'bond',
#               'ether',
#               'complex',
#               'synthesi',
#               'crystal',
#               'structur',
#               'lu'],
#              135: ['particl',
#               'physic',
#               'experi',
#               'search',
#               'decay',
#               'photon',
#               'pseudoscalar',
#               'meson'],
#              136: ['hydroclimatolog',
#               'runoff',
#               'and',
#               'streamflow',
#               'snow',
#               'and',
#               'ice',
#               'initi',
#               'ensembl',
#               'streamflow',
#               'forecast',
#               'remot',
#               'sens',
#               'snow',
#               'cover',
#               'area',
#               'observ'],
#              137: ['social',
#               'context',
#               'messag',
#               'edit',
#               'carswel',
#               'rommetveit'],
#              138: ['interoper',
#               'independ',
#               'heterogen',
#               'distribut',
#               'databas',
#               'methodolog',
#               'case',
#               'support',
#               'interdb',
#               'approach'],
#              139: ['unif', 'linear', 'nonlinear', 'wave', 'optic'],
#              140: ['toward',
#               'emerg',
#               'approach',
#               'softwar',
#               'system',
#               'design'],
#              141: [],
#              142: ['parallel',
#               'comput',
#               'groundwat',
#               'model',
#               'parallel',
#               'reservoir',
#               'simul',
#               'multiphas',
#               'flow',
#               'transport',
#               'model'],
#              143: ['tetrazol',
#               'acet',
#               'acid',
#               'coordin',
#               'polym',
#               'crystal',
#               'structur',
#               'supramolecular',
#               'isom'],
#              144: ['situ',
#               'transmiss',
#               'electron',
#               'microscopi',
#               'observ',
#               'μm',
#               'nm',
#               'cu',
#               'interconnect',
#               'thermal',
#               'stress'],
#              145: ['new',
#               'tetrahymena',
#               'basal',
#               'bodi',
#               'protein',
#               'compon',
#               'identifi',
#               'basal',
#               'bodi',
#               'domain',
#               'structur'],
#              146: ['soen', 'softwar', 'qualiti', 'control'],
#              147: ['enhanc',
#               'topic',
#               'distil',
#               'use',
#               'text',
#               'markup',
#               'tag',
#               'hyperlink'],
#              148: ['global',
#               'transcriptom',
#               'analysi',
#               'reveal',
#               'circadian',
#               'regul',
#               'key',
#               'pathway',
#               'plant',
#               'growth',
#               'develop'],
#              149: ['thiolat',
#               'chitosan',
#               'nanoparticl',
#               'poli',
#               'methyl',
#               'methacryl',
#               'paclitaxel',
#               'cytotox'],
#              150: ['algorithm',
#               'correl',
#               'web',
#               'page',
#               'topic',
#               'correl',
#               'judgment',
#               'algorithm',
#               'base',
#               'weight',
#               'threshold'],
#              151: ['compar', 'educ', 'challeng', 'respons'],
#              152: ['color', 'map', 'kowalski', 'doctrin'],
#              153: ['enhanc',
#               'sprout',
#               'corticospin',
#               'tract',
#               'develop',
#               'adult',
#               'spinal',
#               'cord',
#               'lesion'],
#              154: ['sustain',
#               'develop',
#               'equal',
#               'treatment',
#               'present',
#               'futur'],
#              155: ['carbon',
#               'nanotub',
#               'e',
#               'textil',
#               'antenna',
#               'conform',
#               'antenna',
#               'lightweight',
#               'antenna',
#               'polym',
#               'composit',
#               'conductor',
#               'polym',
#               'composit',
#               'conform',
#               'lightweight',
#               'antenna'],
#              156: [],
#              157: ['synthesi',
#               'prostaglandin',
#               'prospacyclin',
#               'analog',
#               'methyl',
#               'ester'],
#              158: ['semant',
#               'map',
#               'aspect',
#               'orient',
#               'seman',
#               'tic',
#               'context',
#               'orient',
#               'program',
#               'modular',
#               'semant',
#               'modular',
#               'crosscut',
#               'concern'],
#              159: ['technolog', 'birth', 'worth'],
#              160: ['ip',
#               'network',
#               'pipelin',
#               'engin',
#               'random',
#               'access',
#               'memori',
#               'system',
#               'on',
#               'a',
#               'chip',
#               'hardwar',
#               'field',
#               'programm',
#               'gate',
#               'array',
#               'hybrid',
#               'ip',
#               'lookup',
#               'architectur',
#               'fast',
#               'updat'],
#              161: ['design', 'topolog'],
#              162: ['untersuchungen',
#               'generatoren',
#               'für',
#               'gleichverteilt',
#               'zufallszahlen'],
#              163: ['teller', 'book'],
#              164: ['branch',
#               'bound',
#               'model',
#               'choos',
#               'optim',
#               'substat',
#               'locat'],
#              165: ['estim', 'featur', 'distribut', 'binomi', 'data'],
#              166: ['neural',
#               'network',
#               'linear',
#               'arx',
#               'model',
#               'homotopi',
#               'continu',
#               'method',
#               'local',
#               'minimum',
#               'backpropag',
#               'algorithm',
#               'train',
#               'neural',
#               'network',
#               'model',
#               'homotopi',
#               'approach'],
#              167: ['surfac',
#               'wave',
#               'and',
#               'free',
#               'oscil',
#               'seismolog',
#               'lithospher',
#               'and',
#               'upper',
#               'mantl',
#               'shear',
#               'veloc',
#               'structur',
#               'beneath',
#               'la',
#               'vega',
#               'valley',
#               'nevada',
#               'region',
#               'teleseism',
#               'event'],
#              168: ['structur'],
#              169: ['effect',
#               'densiti',
#               'surviv',
#               'boophilusmicroplu',
#               'previous',
#               'unexpos',
#               'cattl'],
#              170: ['exchang', 'transfus', 'sever', 'anaemia'],
#              171: ['norm',
#               'inequ',
#               'exponenti',
#               'type',
#               'holomorph',
#               'function'],
#              172: ['integ',
#               'point',
#               'diophantin',
#               'approxim',
#               'iter',
#               'ration',
#               'map'],
#              173: ['human',
#               'tcell',
#               'maintain',
#               'specif',
#               'function',
#               'even',
#               'condit',
#               'extrem',
#               'restrict',
#               'atp',
#               'product'],
#              174: ['univers', 'test', 'set', 'logic', 'network'],
#              175: ['realtim',
#               'collis',
#               'detect',
#               'virtual',
#               'realiti',
#               'applic'],
#              176: ['microarray',
#               'hu',
#               'em',
#               'algorithm',
#               'statist',
#               'analysi',
#               'method',
#               'gene',
#               'express',
#               'base',
#               'em',
#               'algorithm'],
#              178: ['updat', 'imag', 'intraop', 'mri'],
#              179: ['object',
#               'represent',
#               'classif',
#               'multi',
#               'dimension',
#               'data',
#               'dissimilar',
#               'represent',
#               'dissimilar',
#               'represent',
#               'tool',
#               'data',
#               'classif',
#               'measur'],
#              180: ['effect',
#               'spin',
#               'interact',
#               'qubit',
#               'local',
#               'quantum',
#               'dot'],
#              181: ['inorgan',
#               'compound',
#               'studi',
#               'theori',
#               'of',
#               'phase',
#               'transit',
#               'of',
#               'specif',
#               'substanc',
#               'phase',
#               'diagram',
#               'calcul'],
#              182: ['microbi',
#               'commun',
#               'develop',
#               'biomass',
#               'characterist',
#               'membran',
#               'bioreactor',
#               'differ',
#               'organ',
#               'load'],
#              183: ['edlc',
#               'flexibl',
#               'supercapacitor',
#               'room',
#               'temperatur',
#               'ionic',
#               'liquid',
#               'rtil',
#               'applic',
#               'novel',
#               'room',
#               'temperatur',
#               'ionic',
#               'liquid',
#               'flexibl',
#               'supercapacitor'],
#              184: ['aufbau',
#               'und',
#               'entwicklung',
#               'von',
#               'und',
#               'für',
#               'innov'],
#              185: ['cytolyt',
#               'mechan',
#               'cell',
#               'use',
#               'human',
#               'purifi',
#               'protein'],
#              186: ['context',
#               'base',
#               'navig',
#               'dynam',
#               'link',
#               'gener',
#               'guid',
#               'tour',
#               'hypermedia',
#               'navig',
#               'paradigm',
#               'access',
#               'web',
#               'data'],
#              187: ['ubiquit',
#               'comput',
#               'collabor',
#               'new',
#               'interact',
#               'paradigm',
#               'classroom',
#               'centuri'],
#              188: ['contour',
#               'integr',
#               'represent',
#               'charact',
#               'ration',
#               'conform',
#               'field',
#               'theori'],
#              189: ['est',
#               'ssr',
#               'divers',
#               'soja',
#               'subgenu',
#               'develop',
#               'soybean',
#               'marker',
#               'use',
#               'assess',
#               'genet',
#               'divers',
#               'subgenu',
#               'soja'],
#              190: ['effect',
#               'enrich',
#               'environ',
#               'histolog',
#               'rat',
#               'cerebr',
#               'cortex'],
#              191: ['improv',
#               'transient',
#               'perform',
#               'multidr',
#               'machin',
#               'use',
#               'intersect',
#               'control'],
#              192: ['annual',
#               'particl',
#               'flux',
#               'observ',
#               'heterogen',
#               'urban',
#               'area'],
#              193: ['earthquak',
#               'hazard',
#               'ground',
#               'penetr',
#               'radar',
#               'time',
#               'domain',
#               'impuls',
#               'tdi',
#               'ultra',
#               'wideband',
#               'uwb',
#               'vital',
#               'signal',
#               'detect',
#               'numer',
#               'simul',
#               'uwb',
#               'impuls',
#               'radar',
#               'vital',
#               'signal',
#               'detect',
#               'earthquak',
#               'disast',
#               'site'],
#              194: ['key',
#               'word',
#               'reject',
#               'n',
#               'transplant',
#               'n',
#               'virus',
#               'n',
#               'serpin',
#               'n',
#               'inflamm',
#               'inhibit',
#               'transplant',
#               'vasculopathi',
#               'rat',
#               'aortic',
#               'allograft',
#               'model',
#               'infus',
#               'viral',
#               'serpin'],
#              195: ['semant', 'discours', 'represent'],
#              196: ['disciplin', 'softwar', 'engin'],
#              197: [],
#              198: ['k',
#               'anonym',
#               'locat',
#               'privaci',
#               'spatio',
#               'tempor',
#               'cloak',
#               'unravel',
#               'old',
#               'cloak',
#               'locat',
#               'privaci'],
#              199: ['accuraci',
#               'variabl',
#               'gp',
#               'tropospher',
#               'delay',
#               'measur',
#               'water',
#               'vapor',
#               'western',
#               'mediterranean'],
#              200: ['aneurysm',
#               'bone',
#               'cyst',
#               'hand',
#               'treat',
#               'free',
#               'transfer',
#               'metatars',
#               'proxim',
#               'phalanx',
#               'foot'],
#              201: ['support',
#               'data',
#               'migrat',
#               'relat',
#               'databas',
#               'use',
#               'feder',
#               'approach'],
#              202: ['nonloc',
#               'disloc',
#               'base',
#               'plastic',
#               'incorpor',
#               'gradient',
#               'harden'],
#              203: ['effect',
#               'core',
#               'displac',
#               'orient',
#               'reson',
#               'properti',
#               'nanoegg',
#               'dimer'],
#              204: ['vector', 'space', 'inform'],
#              205: ['ubiquitin',
#               'structur',
#               'white',
#               'matter',
#               'gerbil',
#               'follow',
#               'chronic',
#               'cerebr',
#               'hypoperfus'],
#              206: ['speedboost', 'anytim', 'predict', 'uniform'],
#              207: ['key',
#               'word',
#               'load',
#               'ide',
#               'snp',
#               'haplotyp',
#               'asso',
#               'ciation',
#               'studi',
#               'associ',
#               'studi',
#               'risk',
#               'alzheim',
#               'diseas',
#               'variant',
#               'insulin',
#               'degrad',
#               'enzym'],
#              208: ['concept',
#               'user',
#               'agent',
#               'user',
#               'interfac',
#               'c',
#               'compil'],
#              209: ['busi',
#               'cycl',
#               'financi',
#               'polici',
#               'endogen',
#               'busi',
#               'cycl',
#               'stabil',
#               'polici'],
#              210: ['possibl',
#               'applic',
#               'hyperbar',
#               'oxygen',
#               'technolog',
#               'manag',
#               'urogenit',
#               'renal',
#               'diseas'],
#              211: ['toler', 'chang', 'secur', 'environ', 'visual', 'perspect'],
#              212: [],
#              213: ['challeng', 'privaci', 'data', 'protect', 'europ'],
#              214: ['later',
#               'ventricl',
#               'alzheim',
#               's',
#               'diseas',
#               'magnet',
#               'reson',
#               'imag',
#               'biomark',
#               'neuroimag',
#               'ventricular',
#               'map',
#               'adni',
#               'subject',
#               'correl',
#               'csf',
#               'biomark',
#               'clinic',
#               'declin'],
#              215: ['time', 'driven', 'partit', 'combin', 'logic'],
#              216: [],
#              217: ['auction', 'rank', 'valuat', 'common', 'knowledg'],
#              218: ['die',
#               'innovationsoffens',
#               'für',
#               'die',
#               'region',
#               'ostwürttemberg'],
#              219: ['einwirkung', 'auf', 'natracetessigest'],
#              220: ['panorama',
#               'stitch',
#               'real',
#               'time',
#               'preview',
#               'panoram',
#               'viewfind',
#               'shoot',
#               'panoram',
#               'pictur',
#               'help',
#               'preview'],
#              221: ['equilibrium', 'market', 'sequenti', 'bargain'],
#              222: ['micromachin',
#               'silicon',
#               'interdigit',
#               'bandpass',
#               'filter'],
#              223: ['cost',
#               'channel',
#               'new',
#               'keynesian',
#               'model',
#               'evid',
#               'implic',
#               'mimeo'],
#              224: ['controversi', 'issu', 'cim', 'cad', 'cam', 'cae', 'panel'],
#              225: ['self',
#               'organ',
#               'load',
#               'balanc',
#               'distribut',
#               'autonom',
#               'load',
#               'balanc',
#               'long',
#               'term',
#               'evolut',
#               'i',
#               'introduct',
#               'design',
#               'distribut',
#               'autonom',
#               'load',
#               'balanc',
#               'lte'],
#              226: ['nois',
#               'nois',
#               'field',
#               'dti',
#               'mri',
#               'brain',
#               'estim',
#               'applic',
#               'spatial',
#               'variabl',
#               'nois',
#               'field',
#               'diffus',
#               'tensor',
#               'imag'],
#              227: [],
#              228: [],
#              229: ['analysi',
#               'dynam',
#               'perform',
#               'system',
#               'consid',
#               'forc',
#               'reconstruct',
#               'neural',
#               'network'],
#              230: ['plan',
#               'map',
#               'mobil',
#               'robot',
#               'speed',
#               'control',
#               'path',
#               'find',
#               'chang',
#               'environ'],
#              231: ['integr',
#               'monitor',
#               'model',
#               'perform',
#               'evalu',
#               'methodolog'],
#              232: [],
#              233: ['posit', 'extens', 'diagon', 'connect', 'pattern'],
#              234: ['covellit',
#               'epr',
#               'optic',
#               'absorpt',
#               'nir',
#               'spectroscopi',
#               'copper',
#               'manganes',
#               'iron',
#               'electron',
#               'paramagnet',
#               'reson',
#               'optic',
#               'absorpt',
#               'spectral',
#               'studi',
#               'covellit',
#               'miner'],
#              235: ['bivari',
#               'poisson',
#               'regress',
#               'differ',
#               'of',
#               'poisson',
#               'variat',
#               'inflat',
#               'distribut',
#               'soccer',
#               'analysi',
#               'sport',
#               'data',
#               'use',
#               'bivari',
#               'poisson',
#               'model'],
#              236: ['sensay', 'mobil', 'phone'],
#              237: ['dynam',
#               'queue',
#               'length',
#               'threshold',
#               'share',
#               'memori',
#               'atm',
#               'switch'],
#              238: ['economi', 'mathemat'],
#              239: ['analog',
#               'user',
#               'model',
#               'case',
#               'studi',
#               'individu',
#               'inform',
#               'filter'],
#              240: ['function',
#               'analysi',
#               'probabl',
#               'primari',
#               'secondari',
#               'markov',
#               'chain',
#               'smooth',
#               'banach',
#               'space',
#               'gromov',
#               'hyperbol',
#               'metric',
#               'space'],
#              241: ['newslet',
#               'er',
#               'intern',
#               'human',
#               'dimens',
#               'programm',
#               'global',
#               'environment',
#               'chang',
#               'updat'],
#              242: ['jimi',
#               'hendrix',
#               'meet',
#               'giant',
#               'scream',
#               'buddha',
#               'recreat',
#               'sixti',
#               'via',
#               'backpropag',
#               'time'],
#              243: ['plasma',
#               'immers',
#               'ion',
#               'implant',
#               'materi',
#               'high',
#               'temperatur',
#               'plasma',
#               'immers',
#               'ion',
#               'implant'],
#              244: ['gene',
#               'silenc',
#               'graft',
#               'high',
#               'oleic',
#               'soybean',
#               'transform'],
#              245: ['tax', 'polici', 'economi', 'volum'],
#              246: ['explain', 'rare', 'event', 'intern', 'relat'],
#              247: ['optim', 'criteria', 'decis', 'make', 'ignor'],
#              248: ['acid',
#               'support',
#               'exaf',
#               'h',
#               'mordenit',
#               'h',
#               'zsm',
#               'nox',
#               'ion',
#               'scr',
#               'stabil',
#               'sulfat',
#               'zirconia',
#               'state',
#               'pd',
#               'acid',
#               'support',
#               'select',
#               'reduct',
#               'ch',
#               'studi'],
#              249: ['index',
#               'analog',
#               'synthesi',
#               'mix',
#               'signal',
#               'design',
#               'pattern',
#               'search',
#               'anaconda',
#               'synthesi',
#               'analog',
#               'circuit',
#               'viastochast',
#               'pattern',
#               'search'],
#              250: ['structur', 'hiv', 'revers', 'transcriptas'],
#              251: ['acceler', 'colorect', 'tumour', 'format', 'women'],
#              252: ['comput',
#               'scienc',
#               'distribut',
#               'parallel',
#               'and',
#               'cluster',
#               'comput',
#               'c',
#               'gryphon',
#               'inform',
#               'flow',
#               'base',
#               'approach',
#               'messag',
#               'broker'],
#              253: ['photodiod', 'receiv', 'respons', 'avalanch', 'photodiod'],
#              254: ['lower',
#               'bound',
#               'depth',
#               'threshold',
#               'circuit',
#               'weight'],
#              255: ['electrogastrogram',
#               'electrod',
#               'biopotenti',
#               'model',
#               'human',
#               'surfac',
#               'electrogastrogram',
#               'ac',
#               'dc',
#               'measur'],
#              256: ['phylogenet',
#               'infer',
#               'coloni',
#               'isol',
#               'compris',
#               'season',
#               'microcysti',
#               'bloom',
#               'lake',
#               'taihu',
#               'china'],
#              257: ['quantum', 'physic', 'program', 'complex', 'system'],
#              258: ['novel',
#               'antidiabet',
#               'hypolipidem',
#               'agent',
#               'hydroxyl',
#               'versu',
#               'benzyloxi',
#               'contain',
#               'chroman',
#               'deriv',
#               'sup'],
#              259: ['framework', 'structur', 'distribut', 'object', 'comput'],
#              260: ['une',
#               'applic',
#               'de',
#               'notion',
#               'de',
#               'centr',
#               'et',
#               'index',
#               'rationel',
#               'certain',
#               'langag',
#               'algébriqu'],
#              261: ['capit',
#               'mobil',
#               'econom',
#               'growth',
#               'human',
#               'capit',
#               'accumul',
#               'intern',
#               'taxat',
#               'popul',
#               'growth',
#               'converg',
#               'growth',
#               'rate',
#               'role',
#               'capit',
#               'mobil',
#               'intern',
#               'taxat'],
#              262: ['interact',
#               'parallel',
#               'program',
#               'use',
#               'parascop',
#               'editor'],
#              263: ['algorithm',
#               'detect',
#               'linear',
#               'solut',
#               'nonlinear',
#               'polynomi',
#               'differenti',
#               'equat'],
#              264: ['satellit',
#               'radar',
#               'ice',
#               'monitor',
#               'winter',
#               'navig',
#               'kara',
#               'sea'],
#              265: ['mass',
#               'transfer',
#               'phenomena',
#               'potassium',
#               'carbon',
#               'catalys',
#               'carbon',
#               'steam',
#               'gasif',
#               'reaction',
#               'microbal',
#               'setup'],
#              266: ['synthesi',
#               'monodispers',
#               'hexagon',
#               'cu',
#               'sub',
#               'nanopl'],
#              267: ['corpor', 'semant', 'web'],
#              268: [],
#              269: ['model', 'data', 'currenc', 'financi', 'architectur'],
#              270: ['stem',
#               'central',
# ...
#              916: ['user', 'need', 'isdn', 'seen', 'bank', 'commun'],
#              917: ['chemic',
#               'synthesi',
#               'restrict',
#               'enzym',
#               'recognit',
#               'site',
#               'use',
#               'clone'],
#              918: ['trinitrotoluen',
#               'assess',
#               'occup',
#               'absorpt',
#               'manufactur',
#               'explos'],
#              919: ['review'],
#              920: ['capit', 'movement'],
#              921: ['poli', 'phosphoest', 'ionom', 'scaffold'],
#              922: ['imped', 'method', 'sens', 'proxim', 'interfac'],
#              923: ['effect', 'bc', 'action', 'vortex', 'dynam'],
#              924: ['effect', 'membership', 'trade', 'stand'],
#              925: ['apach', 'site', 'defac'],
#              926: ['admiss',
#               'control',
#               'distribut',
#               'smooth',
#               'video',
#               'use',
#               'patch',
#               'algorithm'],
#              927: ['pair', 'product', 'vacuum', 'radiat'],
#              928: ['use',
#               'po',
#               'inform',
#               'statist',
#               'machin',
#               'translat',
#               'morpholog',
#               'rich',
#               'languag'],
#              929: ['measur',
#               'synthesi',
#               'rate',
#               'muscl',
#               'creatin',
#               'kinas',
#               'myosin',
#               'stabl',
#               'isotop',
#               'mass',
#               'spectrometri'],
#              930: ['epo',
#               'myrinet',
#               'effect',
#               'commun',
#               'support',
#               'parallel',
#               'applic',
#               'run',
#               'cluster',
#               'commod',
#               'workstat'],
#              931: ['shape', 'fractal', 'geometri'],
#              932: ['leerstoelgroep',
#               'milieusysteemanalys',
#               'kosten',
#               'en',
#               'baten',
#               'van',
#               'benefit',
#               'guidelin',
#               'analysi',
#               'econom',
#               'effect',
#               'infrastructur',
#               'project'],
#              933: ['multipl',
#               'sensor',
#               'fault',
#               'detect',
#               'isol',
#               'air',
#               'qualiti',
#               'monitor',
#               'network',
#               'use',
#               'model'],
#              934: ['time', 'seri', 'model', 'global', 'climat', 'chang'],
#              935: ['standard', 'librari', 'haskel'],
#              936: ['dynam',
#               'mainten',
#               'multidimension',
#               'rang',
#               'data',
#               'partit',
#               'parallel',
#               'data',
#               'process'],
#              937: ['control', 'heat', 'equat'],
#              938: ['reoxygen',
#               'result',
#               'cell',
#               'death',
#               'human',
#               'alveolar',
#               'epitheli',
#               'cell'],
#              939: ['method', 'modern', 'mathemat', 'physic'],
#              940: ['ovm',
#               'softwar',
#               'product',
#               'line',
#               'tool',
#               'tool',
#               'autom',
#               'analysi',
#               'ovm'],
#              941: ['knowledg', 'base', 'approach', 'speech', 'recognit'],
#              942: ['dimens',
#               'reduct',
#               'mimo',
#               'maximum',
#               'likelihood',
#               'sphere',
#               'decod',
#               'tree',
#               'search',
#               'decod',
#               'techniqu',
#               'via',
#               'reduc',
#               'dimens',
#               'list',
#               'stack',
#               'algorithm'],
#              943: ['unifi', 'adaboost', 'within', 'margin', 'framework'],
#              944: ['inform',
#               'system',
#               'outsourc',
#               'mix',
#               'integ',
#               'program',
#               'analysi'],
#              945: ['larg',
#               'signal',
#               'network',
#               'analyz',
#               'lsna',
#               'volterra',
#               'seri',
#               'linear',
#               'memori',
#               'effect',
#               'power',
#               'amplifi',
#               'pa',
#               'predistort',
#               'predistort',
#               'linear',
#               'rf',
#               'power',
#               'amplifi'],
#              946: ['group',
#               'test',
#               'dna',
#               'chip',
#               'gener',
#               'design',
#               'decod',
#               'experi'],
#              947: ['autom',
#               'storag',
#               'manag',
#               'qo',
#               'guarante',
#               'virtual',
#               'storag',
#               'system'],
#              948: ['arabian',
#               'sea',
#               'chemistri',
#               'shard',
#               'morpholog',
#               'tephra',
#               'tephra',
#               'quaternari',
#               'sediment',
#               'western',
#               'slope',
#               'lakshadweep',
#               'ridg',
#               'arabian',
#               'sea'],
#              949: ['molecular',
#               'dynam',
#               'particl',
#               'surfac',
#               'chemic',
#               'sputter',
#               'eros',
#               'interact',
#               'hydrogen',
#               'carbon'],
#              950: ['alzheim',
#               's',
#               'diseas',
#               'diagnosi',
#               'eeg',
#               'blind',
#               'sourc',
#               'separ',
#               'amus',
#               'filter',
#               'eeg',
#               'filter',
#               'base',
#               'blind',
#               'sourc',
#               'separ',
#               'bss',
#               'earli',
#               'detect',
#               'alzheim',
#               'diseas'],
#              951: ['composit',
#               'genet',
#               'relationship',
#               'chondrul',
#               'chondrul',
#               'rim',
#               'metal',
#               'matrix',
#               'renazzo',
#               'chondrit'],
#              952: ['great',
#               'expect',
#               'part',
#               'ii',
#               'gener',
#               'expect',
#               'util',
#               'univers',
#               'decis',
#               'rule'],
#              953: ['data', 'represent', 'comput', 'complex'],
#              954: ['conflict', 'cytoplasm', 'male', 'steril', 'revisit'],
#              955: ['effici', 'process', 'aggreg', 'queri', 'olap'],
#              956: ['seca',
#               'atpas',
#               'transloc',
#               'crystal',
#               'structur',
#               'parallel',
#               'dimer',
#               'pre',
#               'protein',
#               'crystal',
#               'structur',
#               'transloc',
#               'atpas',
#               'seca',
#               'thermu',
#               'thermophilu',
#               'reveal',
#               'parallel',
#               'dimer'],
#              957: ['rf', 'parasit', 'oscil', 'high', 'power', 'fel'],
#              958: ['swash',
#               'oscil',
#               'surf',
#               'zone',
#               'steep',
#               'beach',
#               'bichromat',
#               'group',
#               'wave',
#               'groupi',
#               'numer',
#               'experi',
#               'swash',
#               'oscil',
#               'steep',
#               'gentl',
#               'beach'],
#              959: ['nonlinear',
#               'optic',
#               'femtosecond',
#               'fuse',
#               'silica',
#               'applic',
#               'waveguid',
#               'fabric'],
#              960: ['und', 'xml', 'zur', 'repräsent', 'von', 'unschärf'],
#              961: ['improv', 'placement', 'constant', 'delay', 'model'],
#              962: ['ecoop', 'workshop', 'distribut', 'object', 'secur'],
#              963: ['queri', 'hum', 'time', 'seri', 'databas', 'approach'],
#              964: ['munap',
#               'microprogram',
#               'multiprocessor',
#               'architectur',
#               'nonnumer',
#               'process'],
#              965: ['imag',
#               'morph',
#               'trifoc',
#               'morph',
#               'novel',
#               'view',
#               'synthesi',
#               'trifoc',
#               'morph'],
#              966: ['invari', 'logic'],
#              967: ['foreign',
#               'exchang',
#               'reserv',
#               'currenc',
#               'currenc',
#               'composit',
#               'foreign',
#               'exchang',
#               'reserv',
#               'retrospect',
#               'prospect'],
#              968: ['toward', 'softwar', 'engin', 'programm'],
#              969: ['effici',
#               'techniqu',
#               'time',
#               'domain',
#               'analysi',
#               'transmiss',
#               'line',
#               'use',
#               'hilbert',
#               'transform'],
#              970: ['frequenc', 'perform', 'enhanc', 'hemt', 'diamond'],
#              971: ['reliabl',
#               'hierarchi',
#               'semant',
#               'data',
#               'integr',
#               'use',
#               'sort',
#               'prototyp'],
#              972: ['algorithm',
#               'select',
#               'structur',
#               'divers',
#               'set',
#               'compound'],
#              973: ['delay',
#               'propos',
#               'improv',
#               'perform',
#               'tcp',
#               'wireless',
#               'link'],
#              974: ['phytolith',
#               'stabil',
#               'fragil',
#               'taphonomi',
#               'alkalin',
#               'ph',
#               'dissolut',
#               'opal',
#               'stabil',
#               'phytolith',
#               'archaeolog',
#               'record',
#               'dissolut',
#               'studi',
#               'modern',
#               'fossil',
#               'phytolith'],
#              975: ['introduct', 'heterogen', 'optim', 'select', 'theori'],
#              976: ['nano',
#               'structur',
#               'composit',
#               'coat',
#               'ni',
#               'electropl',
#               'sol',
#               'microhard',
#               'wear',
#               'resist',
#               'electrodeposit',
#               'nanostructur',
#               'composit',
#               'coat'],
#              977: ['increas',
#               'effici',
#               'transvers',
#               'electr',
#               'atmospher',
#               'laser',
#               'use',
#               'low',
#               'addit'],
#              978: ['method',
#               'numer',
#               'celesti',
#               'mechan',
#               'minor',
#               'planet',
#               'asteroid',
#               'chaotic',
#               'transport',
#               'chronolog',
#               'complex',
#               'asteroid',
#               'famili'],
#              979: ['mhd',
#               'wave',
#               'plasma',
#               'wave',
#               'and',
#               'instabl',
#               'wave',
#               'wave',
#               'wave',
#               'particl',
#               'interact',
#               'magnetotail',
#               'plasma',
#               'sheet'],
#              980: [],
#              981: ['let', 'put', 'fuel', 'effici', 'perspect'],
#              982: ['interfaci',
#               'slide',
#               'diffus',
#               'stress',
#               'electromigr',
#               'current',
#               'densiti',
#               'influenc',
#               'electr',
#               'current',
#               'diffusion',
#               'accommod',
#               'slide'],
#              983: ['formal', 'metaphor', 'user', 'interfac'],
#              984: ['book',
#               'collect',
#               'sequenc',
#               'align',
#               'translat',
#               'detect',
#               'uniqu',
#               'word',
#               'find',
#               'translat',
#               'scan',
#               'book',
#               'collect'],
#              985: ['nation',
#               'statu',
#               'trend',
#               'program',
#               'marin',
#               'environment',
#               'qualiti',
#               'toxic',
#               'contamin',
#               'long',
#               'island',
#               'sound'],
#              986: ['tunabl', 'integr', 'duplex', 'isol', 'cmo'],
#              987: ['probabilist',
#               'approach',
#               'concurr',
#               'map',
#               'local',
#               'mobil',
#               'robot'],
#              988: ['character',
#               'optic',
#               'perform',
#               'advanc',
#               'technolog',
#               'aot'],
#              989: [],
#              990: ['select',
#               'optic',
#               'sensor',
#               'base',
#               'new',
#               'type',
#               'ionophor',
#               'chlorid',
#               'complex',
#               'caviti'],
#              991: ['addit',
#               'key',
#               'word',
#               'and',
#               'phrase',
#               'storag',
#               'manag',
#               'ment',
#               'index',
#               'quadtre',
#               'swap',
#               'cach',
#               'miss',
#               'page',
#               'factor',
#               'quadtre',
#               'matric',
#               'memori',
#               'parallel'],
#              992: ['nonhomogen',
#               'media',
#               'filter',
#               'nois',
#               'pixel',
#               'magnet',
#               'reson',
#               'imag',
#               'classif',
#               'algorithm',
#               'nois',
#               'level',
#               'mr',
#               'brain',
#               'classif',
#               'method',
#               'base',
#               'multiscal',
#               'multiblock',
#               'fuzzi'],
#              993: ['troposat',
#               'use',
#               'usabl',
#               'satellit',
#               'data',
#               'tropospher',
#               'research'],
#              994: ['classif',
#               'vascular',
#               'dementia',
#               'cardiovascular',
#               'health',
#               'studi',
#               'cognit',
#               'studi'],
#              995: ['raman',
#               'spectroscopi',
#               'natur',
#               'leiteit',
#               'comparison',
#               'synthesis',
#               'miner'],
#              996: ['hmm',
#               'predict',
#               'discrimin',
#               'beta',
#               'barrel',
#               'membran',
#               'protein'],
#              997: ['key',
#               'word',
#               'high',
#               'pressur',
#               'freez',
#               'immunogold',
#               'em',
#               'membran',
#               'associ',
#               'mung',
#               'bean',
#               'sucros',
#               'bind',
#               'protein',
#               'tonoplast',
#               'kda',
#               'sucros',
#               'bind',
#               'protein',
#               'develop',
#               'mung',
#               'bean',
#               'seed'],
#              998: ['composit',
#               'center',
#               'scheme',
#               'multidimension',
#               'conserv',
#               'law'],
#              999: ['scan',
#               'infrar',
#               'radiomet',
#               'measur',
#               'temperatur',
#               'differ'],
#              1000: ['exploratori', 'studi', 'web', 'servic', 'internet'],
#              1001: ['quantit', 'comparison', 'control', 'method', 'microdata'],
#              ...})

# %%
dataset['paper']
# Out:
#         Id                                              Title  Year  \
# 0        1  Stitching videos streamed by mobile phones in ...  2009
# 1        2           A nonlocal convection–diffusion equation  2007
# 2        3                             Area Effects in Cepaea  1963
# 3        4  Multiple paternity in a natural population of ...  2005
# 4        5      Complexity of Finding Short Resolution Proofs  1997
# 5        6  A software system for large dynamic maps based...  2001
# 6        7              Natural History of the Psychoneuroses  1959
# 7        8  145 GROWTH HORMONE RECEPTORS AND THE ONSET OF ...  1985
# 8        9  Hypermethylation of the <I>TPEF/HPP1</I> Gene ...  2005
# 9       10           RUC Short-Range Ensemble Forecast System     0
# 10      11  A Formal Approach to Service Component Archite...  2006
# 11      12  FIBER: A Generalized Framework for Auto-tuning...  2003
# 12      13  Modeling and verifying a broad array of networ...  2009
# 13      14  High-resolution monitoring of nitrate variatio...     0
# 14      15  Data object creation and display techniques fo...  1993
# 15      16  Skew-Circulant Preconditioners for Systems of ...  2000
# 16      17  A Framework for the Parallel Processing of Dat...  1990
# 17      18  Synthesis of endomorphic models for event base...  1993
# 18      19                                 Real-Time Automata  2001
# 19      20                      Googlemetrie und Arbeitsmarkt  2009
# 20      21  Combined laparoscopic and thoracoscopic approa...  1999
# 21      22  Optimal Wage and Income Taxation with Wage Unc...  1987
# 22      23  Universality Classes for Spreading Phenomena: ...  1985
# 23      24  Augmented equivalence principle algorithm at l...  2010
# 24      25  Do CFG-Based Language Models Need Agreement Co...  2001
# 25      26  Potentiation of the effects of reward-related ...  1991
# 26      27  Using Reactive and Adaptive Behaviors to Play ...  2000
# 27      28               E-learning System as Part of the KMS  2002
# 28      29  Newer approaches to the diagnosis of early ons...  2006
# 29      30                                             Epilog     0
# ...    ...                                                ...   ...
# 1970  1959  Bounds of parameter uncertainties for robust s...  1998
# 1971  1960  Ordinary differential equations and the symmet...  1982
# 1972  1961  Fast subspace tracking by a novel information ...  1997
# 1973  1962  Representing and Simulating Consumers' Behavio...  2004
# 1974  1963  Organizing Flexibility: The Flexible Firm in a...  2001
# 1975  1964  Phase ordering in the Ising model with conserv...  1995
# 1976  1965  Thermoelastic Damping in Nanomechanical Resona...  2006
# 1977  1966  Advances in Neural Information Processing Syst...  1998
# 1978  1967  Experimental and theoretical studies of revers...  1992
# 1979  1968  Bayesian image estimation from an incomplete s...  2003
# 1980  1969  Parallel String Matching Algorithms based on D...  1999
# 1981  1970  Backtracking-Free Dictionary Access Method for...  1994
# 1982  1971  Software Technologies for Embedded and Ubiquit...  2011
# 1983  1972             Acoustic Properties of Stop Consonants  1957
# 1984  1973  Developing and Implementing Decision Support S...  1995
# 1985  1974  An Anomaly Traffic Detection Method for VoIP A...  2009
# 1986  1975  Evidence for Triangular Moment Arrangements in...  1959
# 1987  1976                                                NaN  1996
# 1988  1977   Lymphotactin Acts as an Innate Mucosal Adjuvant1     0
# 1989  1978  On Simulating Subjective Evaluation Using Comb...  2007
# 1990  1979  Adaptive rate allocation in a joint source/cha...  1996
# 1991  1980  Iterated Prisoner''s Dilemma with Choice and R...  1994
# 1992  1981  Control of doubly-fed induction generator syst...  2011
# 1993  1982         Overview of Nucleic Acid Analysis Programs  1999
# 1994  1983  An embedded 4-channel real-time multimedia cod...  2006
# 1995  1984  Model Checking Abstract State Machines with An...  2007
# 1996  1985  Taming the Computational Complexity of Combina...  1999
# 1997  1986            Conjunctive Query Containment Revisited  1997
# 1998  1987    Autosomal dominant inheritance of small kidneys  1989
# 1999  1988  Evidence for the origin of reconstruction of t...  1992
#
#       ConferenceId  JournalId  \
# 0              167          0
# 1                0       7234
# 2                0      16867
# 3                0       6130
# 4              158          0
# 5              341          0
# 6                0      17639
# 7                0       4084
# 8                0       3943
# 9                0          0
# 10            2397          0
# 11            1231          0
# 12               0      16666
# 13               0       6000
# 14            1037          0
# 15            1389          0
# 16               0        253
# 17            4072          0
# 18               0         94
# 19               0      13528
# 20               0       3456
# 21               0          0
# 22               0       8570
# 23               0       8518
# 24            1390          0
# 25               0       8097
# 26               0        233
# 27            1452          0
# 28               0       2620
# 29               0          0
# ...            ...        ...
# 1970             0        871
# 1971             0          0
# 1972          4998          0
# 1973           254          0
# 1974             0       4651
# 1975             0       8569
# 1976             0       5612
# 1977           187          0
# 1978             0          0
# 1979          1068         -1
# 1980           736          0
# 1981           587          0
# 1982             0          0
# 1983             0       8447
# 1984             0       6071
# 1985             0          0
# 1986             0          0
# 1987          4803          0
# 1988             0          0
# 1989          1351          0
# 1990          2983          0
# 1991             0          0
# 1992          1006          0
# 1993             0       1657
# 1994           169          0
# 1995             0        329
# 1996            64          0
# 1997            24          0
# 1998             0       7557
# 1999             0       8570
#
#                                                 Keyword
# 0      mobile video capturing|real-time|video stitching
# 1     Nonlocal diffusion; Convection–diffusion; Asym...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     Keywords: methylation, epigenetic, metastasis,...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
# 1975                                                NaN
# 1976  Thermoelastic damping,Generalized thermoelasti...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
# 1982                                                NaN
# 1983                                                NaN
# 1984  Decisionmaking, Decision support systems, Rese...
# 1985  Keywords IPFIX, VoIP, anomaly, detection, algo...
# 1986                                                NaN
# 1987                                                NaN
# 1988                                                NaN
# 1989                                                NaN
# 1990                                                NaN
# 1991                                                NaN
# 1992                                                NaN
# 1993                                                NaN
# 1994                                                NaN
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
# [2000 rows x 6 columns]
